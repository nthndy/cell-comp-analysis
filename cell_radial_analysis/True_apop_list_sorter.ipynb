# %%
import numpy as np
import os

# %%
root_path = '/home/nathan/data/kraken/h2b/giulia/apop_list'
list_of_npz = os.listdir(root_path)

# %%
list_of_IDs = []
for i in list_of_npz:
    var_name = i[0:-4]
    if 'fake' in var_name:
        continue
    else:
        with np.load(os.path.join(root_path, i)) as data:
             ID = data['ID']
        movie = 
        pos = 
        gfp/rfp etc
        list_of_IDs.append(ID)

# %%
list_of_IDs
# Out:
# [array('21', dtype='<U2'),
#  array('146', dtype='<U3'),
#  array('18', dtype='<U2'),
#  array('5', dtype='<U1'),
#  array('6', dtype='<U1'),
#  array('37', dtype='<U2'),
#  array('792', dtype='<U3'),
#  array('28', dtype='<U2'),
#  array('527', dtype='<U3'),
#  array('727', dtype='<U3'),
#  array('68', dtype='<U2'),
#  array('1', dtype='<U1'),
#  array('78', dtype='<U2'),
#  array('5', dtype='<U1'),
#  array('736', dtype='<U3'),
#  array('147', dtype='<U3'),
#  array('302', dtype='<U3'),
#  array('12', dtype='<U2'),
#  array('623', dtype='<U3'),
#  array('864', dtype='<U3'),
#  array('1767', dtype='<U4'),
#  array('256', dtype='<U3'),
#  array('470', dtype='<U3'),
#  array('93', dtype='<U2'),
#  array('39', dtype='<U2'),
#  array('6', dtype='<U1'),
#  array('72', dtype='<U2'),
#  array('64', dtype='<U2'),
#  array('731', dtype='<U3'),
#  array('57', dtype='<U2'),
#  array('33', dtype='<U2'),
#  array('504', dtype='<U3'),
#  array('45', dtype='<U2'),
#  array('9', dtype='<U1'),
# ...

# %%
with np.load(os.path.join(root_path, list_of_npz[0])) as data:
    print(data['ID'])
# Out:
# 21
