# %% [markdown]
# # NAPARI visualization of UNet Training Data
#
# You can use this notebook to view, modified and save out training data for UNet models
#
# Labels:
# + 0 - background
# + 1 - GFP/Phase
# + 2 - RFP
#
#
# Extra key bindings:
# + 'w' - calculate weightmap
# + 'q' - calculate custom annotated weightmap (weightmask * weightmap)
# + '/' - save label current displayed
# + 's' - save all labels
# + 'o' - output all weightmaps and metadata for tfrecord creation
# + '\>' - grow the label under the mouse cursor
# + '\<' - shrink the label under the mouse cursor
# + 'h' - fill holes in cell mask under the mouse cursor
# + '0' - clear all cell labels that aren't currently under the cursor
# + 'n' - count cells (will be updated to collect more stats)
# + 'g' - output gaussian noise images for missing fluorescence images
# + 'm' - output results of "measurements" function, note- think you need to be on the GFP layer for this to work?

# %% [markdown]
# ---
#
# ```
# Authors:
# - Alan R. Lowe (a.lowe@ucl.ac.uk)
# - Nathan J. Day (nathan.day.16@ucl.ac.uk)
# ```

# %% [markdown]
# ---
# ## Set up the data path, channel(s) used, weight amplitude and the number of images to load

# %%
DATA_PATH = '/Users/nathanday/lowe_lab/fucci'
#DATA_PATH = '/Users/nathanday/lowe_lab/training_data'
#DATA_PATH = '/home/nathan/analysis/fucci/working_dir/all/full_stack'

WEIGHT_AMPLITUDE = 0.
ACQUISITION_CHANNELS = ['PHASE', 'GFP','RFP'] #, 'GFP' , 'RFP'] #complete sets
INCOMPLETE_CHANNELS = [] # 'IRFP'] #list here if sets incomplete ie some images missing and need to supplement w gaus noise
#NUMBER_OF_IMAGES_TO_LOAD = 10 #in each set, from index 0, loads in numerical order, if all images desired then enter 'ALL'
INDEX_OF_IMAGES = 'ALL' #[0,10] #enter [min, max] or 'ALL'
#INDEX_OF_IMAGES = [minimum:maximum]
#ACQUISITION_CHANNELS = ['GFP', 'RFP']

# %% [markdown]
# ---

# %%
import os
import re
import enum
import json
import csv
import napari
import pandas as pd
from skimage import io
from skimage.util import random_noise
import numpy as np
from scipy import ndimage
from itertools import islice

from scipy.ndimage.morphology import distance_transform_edt
from scipy.ndimage import gaussian_filter

import matplotlib.pyplot as plt

# %%
@enum.unique
class Channels(enum.Enum):
    BRIGHTFIELD = 0 
    GFP = 1
    RFP = 2
    IRFP = 3
    PHASE = 4
    WEIGHTS = 98
    MASK = 99

# %%
global filename

def strip_modified_filename(filename):
    if filename.endswith('.modified.tif'):
        stripped_fn = filename[:-len('.modified.tif')]
        return stripped_fn
    return filename

def make_folder(foldername):
    if os.path.exists(foldername):
        return
    os.mkdir(foldername)
    
def file_root(filename):  #searches for the filename pattern inside the given filename, returns the result of that search as grps
    FILENAME_PATTERN = r'([a-zA-Z0-9]+)_([a-zA-Z0-9]+)_*.tif'
    grps = re.search(FILENAME_PATTERN, filename)
    return grps

def load_training_data(pth, channels=[Channels.GFP, Channels.RFP]):
    """ load training data for visualisation with napari"""
          
    # find the sets and sort them
    global sets #allows sets to be called from another function
    sets = [f for f in os.listdir(pth) if os.path.isdir(os.path.join(pth, f))]
    sets.sort(key = lambda s: int(s[3:]))
    
    def set_filename_format(filename): #both functions below serve to find filenames regardless of x_gfp.tif or gfp_x.tif
        grps = file_root(filename)
        
        if grps.group(1) in [c.name.lower() for c in all_channels]: #if a feature about the fn pattern is in the channel name (ie gfp) then FNFMT = 2, allowing for x_gfp.tif or gfp_x.tif to be sorted 
            FILENAME_FORMAT = 2 #gfp_x.tif
        else:
            FILENAME_FORMAT = 1 #x_gfp.tif
                        
        def filename_formatter(filename, channel):
            # assert(channel in [c.name.lower() for c in all_channels])
            grps = file_root(filename)

            return f'{grps.group(FILENAME_FORMAT)}_{channel}.tif'
            # return '{}_{}.tif'.format(*[channel, grps.group(FILENAME_FORMAT)])
        
        return filename_formatter
        
    all_channels = [Channels.MASK, Channels.WEIGHTS]+channels
    global files
    files = {k:{'files':[], 'data':[], 'sets':[], 'path':[]} for k in all_channels}
    all_channels.remove(Channels.WEIGHTS)
       
    for s in sets:

        # root_folders
        l_root = os.path.join(pth, s, 'labels')
        
        # check that this folder exists 
        if not os.path.exists(l_root):
            raise IOError(f'{l_root} does not exist. Do you need to rename label -> labels?')

        # get the training label files
        label_files = [f for f in os.listdir(l_root) if f.endswith('.tif')]
                
        # sort to remove unmodified files and replace with the modified files
        unmodified_files, modified_files = [], []
        
        #for index, item in enumerate(islice(items, limit)):
        for i, f in enumerate(label_files): #introducing islice here allows you to choose size of dataset! but only in a random order
            if f.endswith('.modified.tif'):
                modified_files.append(strip_modified_filename(f))
            else:
                unmodified_files.append(f)
                
        unmodified_files = list(set(unmodified_files).difference(set(modified_files))) #this is only unmod where mod doesnt exist
        label_files_full = unmodified_files + [f+'.modified.tif' for f in modified_files]    
        label_files_full.sort(key = lambda f: int(f[0:4])) #sorts files numerically

        #N = NUMBER_OF_IMAGES_TO_LOAD
        #n = INDEX_OF_IMAGES[0]
        #m = INDEX_OF_IMAGES[1]
        
        if INDEX_OF_IMAGES == 'ALL':
            label_files = label_files_full
        else:
            n = INDEX_OF_IMAGES[0]
            m = INDEX_OF_IMAGES[1]
            label_files = label_files_full[n:m] #cuts list of files to n->m images       
            #label_files = label_files_full[INDEX_OF_IMAGES]

        """
        if N == 'ALL':
            label_files = label_files_full
        elif N > 0:
            label_files = label_files_full[:N] #cuts list of files to N images
        else:
            label_files = label_files_full[n:m] #cuts list of files to n->m images       
        ## MAKE THIS ELIF TIDIER SO ONLY ONE INPUT IS REQUIRED ##        
        """
        global fnfmt
        fnfmt = set_filename_format(label_files[0]) #why only label_files[0]? -> bc only need one example to set the fnfmt
                        
        files[Channels.MASK]['path'] += [s+'/labels/'+f for f in label_files]
        files[Channels.MASK]['files'] += [strip_modified_filename(f) for f in label_files]
        files[Channels.MASK]['data'] += [io.imread(os.path.join(l_root, f)) for f in label_files]
        files[Channels.MASK]['sets'] += [s] * len(label_files)
        
        for channel in channels:
            
           #if cfiles channel.name.lower dir doesnt contain gfp or rfp then add option to create noise data,
            channel_dir = os.path.join(pth, s, channel.name.lower())            
            #if os.path.exists(channel_dir): #if fluor/phase channels exist, continue as norm
            cfiles = [fnfmt(l, channel.name.lower()) for l in label_files]
            files[channel]['path'] += [s+'/'+channel.name.lower()+'/'+f for f in cfiles]
            files[channel]['files'] += cfiles #filenames
            files[channel]['data'] += [io.imread(os.path.join(pth, s, channel.name.lower(), f)) for f in cfiles] #actualdata
            files[channel]['sets'] += [s] * len(label_files)
            
        # now look for weights 
        w_root = os.path.join(pth, s, 'weights') ### change this back to 'weights' and have func to rename previous weight folder?
        #if os.path.exists(w_root):
        wfiles = [fnfmt(l, 'weights') for l in label_files]
        for weight_file in wfiles:
            files[Channels.WEIGHTS]['path'] += [f'{s}/weights/{weight_file}']
            files[Channels.WEIGHTS]['files'] += [weight_file]
            files[Channels.WEIGHTS]['sets'] += [s]
            if os.path.exists(os.path.join(w_root, weight_file)):
                files[Channels.WEIGHTS]['data'] += [io.imread(os.path.join(w_root, weight_file)).astype(np.float32)]
            else:
                print(f'Adding empty weight file: {weight_file}')
                mask_shape = files[channels[0]]['data'][0].shape
                files[Channels.WEIGHTS]['data'] += [np.zeros(mask_shape, dtype=np.float32)]
                        

    w_root = os.path.join(pth, s, 'weights')
                                                         
    # now make image stacks 
    for channel in files.keys():
        for i, im in enumerate(files[channel]['data']):
            print(channel, files[channel]['path'][i], im.shape, im.dtype)
        
        files[channel]['data'] = np.stack(files[channel]['data'], axis=0)
        
    global shape
    shape = files[channels[0]]['data'][0].shape
    
    return files

# %%
channels = [Channels[c.upper()] for c in ACQUISITION_CHANNELS]
data = load_training_data(DATA_PATH, channels)
# Out:
# /Users/nathanday/lowe_lab/analysis/tifffile.py:2170: UserWarning: failed to import _tifffile.decodepackbits
#   warnings.warn("failed to import %s" % module_function)
# /Users/nathanday/lowe_lab/analysis/tifffile.py:2170: UserWarning: failed to import _tifffile.decodelzw
#   warnings.warn("failed to import %s" % module_function)
# /Users/nathanday/lowe_lab/analysis/tifffile.py:2170: UserWarning: failed to import _tifffile.unpackints
#   warnings.warn("failed to import %s" % module_function)
# Adding empty weight file: 0000_weights.tif
# Adding empty weight file: 0001_weights.tif
# Adding empty weight file: 0002_weights.tif
# Adding empty weight file: 0003_weights.tif
# Adding empty weight file: 0004_weights.tif
# Adding empty weight file: 0005_weights.tif
# Adding empty weight file: 0006_weights.tif
# Adding empty weight file: 0007_weights.tif
# Adding empty weight file: 0008_weights.tif
# Adding empty weight file: 0009_weights.tif
# Adding empty weight file: 0010_weights.tif
# Adding empty weight file: 0011_weights.tif
# Adding empty weight file: 0012_weights.tif
# Adding empty weight file: 0013_weights.tif
# Adding empty weight file: 0014_weights.tif
# Adding empty weight file: 0015_weights.tif
# Adding empty weight file: 0016_weights.tif
# Adding empty weight file: 0017_weights.tif
# Adding empty weight file: 0018_weights.tif
# Adding empty weight file: 0019_weights.tif
# Adding empty weight file: 0020_weights.tif
# Adding empty weight file: 0021_weights.tif
# Adding empty weight file: 0022_weights.tif
# Adding empty weight file: 0023_weights.tif
# Adding empty weight file: 0024_weights.tif
# Adding empty weight file: 0025_weights.tif
# Adding empty weight file: 0026_weights.tif
# Adding empty weight file: 0027_weights.tif
# Adding empty weight file: 0028_weights.tif
# Adding empty weight file: 0029_weights.tif
# Adding empty weight file: 0030_weights.tif
# Adding empty weight file: 0031_weights.tif
# Adding empty weight file: 0032_weights.tif
# Adding empty weight file: 0033_weights.tif
# Adding empty weight file: 0034_weights.tif
# Adding empty weight file: 0035_weights.tif
# Adding empty weight file: 0036_weights.tif
# Adding empty weight file: 0037_weights.tif
# Adding empty weight file: 0038_weights.tif
# Adding empty weight file: 0039_weights.tif
# Adding empty weight file: 0040_weights.tif
# Adding empty weight file: 0041_weights.tif
# Adding empty weight file: 0042_weights.tif
# Adding empty weight file: 0043_weights.tif
# Adding empty weight file: 0044_weights.tif
# Adding empty weight file: 0045_weights.tif
# Adding empty weight file: 0046_weights.tif
# Adding empty weight file: 0047_weights.tif
# Adding empty weight file: 0048_weights.tif
# Adding empty weight file: 0049_weights.tif
# Adding empty weight file: 0050_weights.tif
# Adding empty weight file: 0051_weights.tif
# Adding empty weight file: 0052_weights.tif
# Adding empty weight file: 0053_weights.tif
# Adding empty weight file: 0054_weights.tif
# Adding empty weight file: 0055_weights.tif
# Adding empty weight file: 0056_weights.tif
# Adding empty weight file: 0057_weights.tif
# Adding empty weight file: 0058_weights.tif
# Adding empty weight file: 0059_weights.tif
# Adding empty weight file: 0060_weights.tif
# Adding empty weight file: 0061_weights.tif
# Adding empty weight file: 0062_weights.tif
# Adding empty weight file: 0063_weights.tif
# Adding empty weight file: 0064_weights.tif
# Adding empty weight file: 0065_weights.tif
# Adding empty weight file: 0066_weights.tif
# Adding empty weight file: 0067_weights.tif
# Adding empty weight file: 0068_weights.tif
# Adding empty weight file: 0069_weights.tif
# Adding empty weight file: 0070_weights.tif
# Adding empty weight file: 0071_weights.tif
# Adding empty weight file: 0072_weights.tif
# Adding empty weight file: 0073_weights.tif
# Adding empty weight file: 0074_weights.tif
# Adding empty weight file: 0075_weights.tif
# Adding empty weight file: 0076_weights.tif
# Adding empty weight file: 0077_weights.tif
# Adding empty weight file: 0078_weights.tif
# Adding empty weight file: 0079_weights.tif
# Adding empty weight file: 0080_weights.tif
# Adding empty weight file: 0081_weights.tif
# Adding empty weight file: 0082_weights.tif
# Adding empty weight file: 0083_weights.tif
# Adding empty weight file: 0084_weights.tif
# Adding empty weight file: 0085_weights.tif
# Adding empty weight file: 0086_weights.tif
# Adding empty weight file: 0087_weights.tif
# Adding empty weight file: 0088_weights.tif
# Adding empty weight file: 0089_weights.tif
# Adding empty weight file: 0090_weights.tif
# Adding empty weight file: 0091_weights.tif
# Adding empty weight file: 0092_weights.tif
# Adding empty weight file: 0093_weights.tif
# Adding empty weight file: 0094_weights.tif
# Adding empty weight file: 0095_weights.tif
# Adding empty weight file: 0096_weights.tif
# Adding empty weight file: 0097_weights.tif
# Adding empty weight file: 0098_weights.tif
# Adding empty weight file: 0099_weights.tif
# Adding empty weight file: 0100_weights.tif
# Adding empty weight file: 0101_weights.tif
# Adding empty weight file: 0102_weights.tif
# Adding empty weight file: 0103_weights.tif
# Adding empty weight file: 0104_weights.tif
# Adding empty weight file: 0105_weights.tif
# Adding empty weight file: 0106_weights.tif
# Adding empty weight file: 0107_weights.tif
# Adding empty weight file: 0108_weights.tif
# Adding empty weight file: 0109_weights.tif
# Adding empty weight file: 0110_weights.tif
# Adding empty weight file: 0111_weights.tif
# Adding empty weight file: 0112_weights.tif
# Adding empty weight file: 0113_weights.tif
# Adding empty weight file: 0114_weights.tif
# Adding empty weight file: 0115_weights.tif
# Adding empty weight file: 0116_weights.tif
# Adding empty weight file: 0117_weights.tif
# Adding empty weight file: 0118_weights.tif
# Adding empty weight file: 0119_weights.tif
# Adding empty weight file: 0120_weights.tif
# Adding empty weight file: 0121_weights.tif
# Adding empty weight file: 0122_weights.tif
# Adding empty weight file: 0123_weights.tif
# Adding empty weight file: 0124_weights.tif
# Adding empty weight file: 0125_weights.tif
# Adding empty weight file: 0126_weights.tif
# Adding empty weight file: 0127_weights.tif
# Adding empty weight file: 0128_weights.tif
# Adding empty weight file: 0129_weights.tif
# Adding empty weight file: 0130_weights.tif
# Adding empty weight file: 0131_weights.tif
# Adding empty weight file: 0132_weights.tif
# Adding empty weight file: 0133_weights.tif
# Adding empty weight file: 0134_weights.tif
# Adding empty weight file: 0135_weights.tif
# Adding empty weight file: 0136_weights.tif
# Adding empty weight file: 0137_weights.tif
# Adding empty weight file: 0138_weights.tif
# Adding empty weight file: 0139_weights.tif
# Adding empty weight file: 0140_weights.tif
# Adding empty weight file: 0141_weights.tif
# Adding empty weight file: 0142_weights.tif
# Adding empty weight file: 0143_weights.tif
# Adding empty weight file: 0144_weights.tif
# Adding empty weight file: 0145_weights.tif
# Adding empty weight file: 0146_weights.tif
# Adding empty weight file: 0147_weights.tif
# Adding empty weight file: 0148_weights.tif
# Adding empty weight file: 0149_weights.tif
# Adding empty weight file: 0150_weights.tif
# Adding empty weight file: 0151_weights.tif
# Adding empty weight file: 0152_weights.tif
# Adding empty weight file: 0153_weights.tif
# Adding empty weight file: 0154_weights.tif
# Adding empty weight file: 0155_weights.tif
# Adding empty weight file: 0156_weights.tif
# Adding empty weight file: 0157_weights.tif
# Adding empty weight file: 0158_weights.tif
# Adding empty weight file: 0159_weights.tif
# Adding empty weight file: 0160_weights.tif
# Adding empty weight file: 0161_weights.tif
# Adding empty weight file: 0162_weights.tif
# Adding empty weight file: 0163_weights.tif
# Adding empty weight file: 0164_weights.tif
# Adding empty weight file: 0165_weights.tif
# Adding empty weight file: 0166_weights.tif
# Adding empty weight file: 0167_weights.tif
# Adding empty weight file: 0168_weights.tif
# Adding empty weight file: 0169_weights.tif
# Adding empty weight file: 0170_weights.tif
# Adding empty weight file: 0171_weights.tif
# Adding empty weight file: 0172_weights.tif
# Adding empty weight file: 0173_weights.tif
# Adding empty weight file: 0174_weights.tif
# Adding empty weight file: 0175_weights.tif
# Adding empty weight file: 0176_weights.tif
# Adding empty weight file: 0177_weights.tif
# Adding empty weight file: 0178_weights.tif
# Adding empty weight file: 0179_weights.tif
# Adding empty weight file: 0180_weights.tif
# Adding empty weight file: 0181_weights.tif
# Adding empty weight file: 0182_weights.tif
# Adding empty weight file: 0183_weights.tif
# Adding empty weight file: 0184_weights.tif
# Adding empty weight file: 0185_weights.tif
# Adding empty weight file: 0186_weights.tif
# Adding empty weight file: 0187_weights.tif
# Adding empty weight file: 0188_weights.tif
# Adding empty weight file: 0189_weights.tif
# Adding empty weight file: 0190_weights.tif
# Adding empty weight file: 0191_weights.tif
# Adding empty weight file: 0192_weights.tif
# Adding empty weight file: 0193_weights.tif
# Adding empty weight file: 0194_weights.tif
# Adding empty weight file: 0195_weights.tif
# Adding empty weight file: 0196_weights.tif
# Adding empty weight file: 0197_weights.tif
# Adding empty weight file: 0198_weights.tif
# Adding empty weight file: 0199_weights.tif
# Adding empty weight file: 0200_weights.tif
# Adding empty weight file: 0201_weights.tif
# Adding empty weight file: 0202_weights.tif
# Adding empty weight file: 0203_weights.tif
# Adding empty weight file: 0204_weights.tif
# Adding empty weight file: 0205_weights.tif
# Adding empty weight file: 0206_weights.tif
# Adding empty weight file: 0207_weights.tif
# Adding empty weight file: 0208_weights.tif
# Adding empty weight file: 0209_weights.tif
# Adding empty weight file: 0210_weights.tif
# Adding empty weight file: 0211_weights.tif
# Adding empty weight file: 0212_weights.tif
# Adding empty weight file: 0213_weights.tif
# Adding empty weight file: 0214_weights.tif
# Adding empty weight file: 0215_weights.tif
# Adding empty weight file: 0216_weights.tif
# Adding empty weight file: 0217_weights.tif
# Adding empty weight file: 0218_weights.tif
# Adding empty weight file: 0219_weights.tif
# Adding empty weight file: 0220_weights.tif
# Adding empty weight file: 0221_weights.tif
# Adding empty weight file: 0222_weights.tif
# Adding empty weight file: 0223_weights.tif
# Adding empty weight file: 0224_weights.tif
# Adding empty weight file: 0225_weights.tif
# Adding empty weight file: 0226_weights.tif
# Adding empty weight file: 0227_weights.tif
# Adding empty weight file: 0228_weights.tif
# Adding empty weight file: 0229_weights.tif
# Adding empty weight file: 0230_weights.tif
# Adding empty weight file: 0231_weights.tif
# Adding empty weight file: 0232_weights.tif
# Adding empty weight file: 0233_weights.tif
# Adding empty weight file: 0234_weights.tif
# Adding empty weight file: 0235_weights.tif
# Adding empty weight file: 0236_weights.tif
# Adding empty weight file: 0237_weights.tif
# Adding empty weight file: 0238_weights.tif
# Adding empty weight file: 0239_weights.tif
# Adding empty weight file: 0240_weights.tif
# Adding empty weight file: 0241_weights.tif
# Adding empty weight file: 0242_weights.tif
# Adding empty weight file: 0243_weights.tif
# Adding empty weight file: 0244_weights.tif
# Adding empty weight file: 0245_weights.tif
# Adding empty weight file: 0246_weights.tif
# Adding empty weight file: 0247_weights.tif
# Adding empty weight file: 0248_weights.tif
# Adding empty weight file: 0249_weights.tif
# Adding empty weight file: 0250_weights.tif
# Adding empty weight file: 0251_weights.tif
# Adding empty weight file: 0252_weights.tif
# Adding empty weight file: 0253_weights.tif
# Adding empty weight file: 0254_weights.tif
# Adding empty weight file: 0255_weights.tif
# Adding empty weight file: 0256_weights.tif
# Adding empty weight file: 0257_weights.tif
# Adding empty weight file: 0258_weights.tif
# Adding empty weight file: 0259_weights.tif
# Adding empty weight file: 0260_weights.tif
# Adding empty weight file: 0261_weights.tif
# Adding empty weight file: 0262_weights.tif
# Adding empty weight file: 0263_weights.tif
# Adding empty weight file: 0264_weights.tif
# Adding empty weight file: 0265_weights.tif
# Adding empty weight file: 0266_weights.tif
# Adding empty weight file: 0267_weights.tif
# Adding empty weight file: 0268_weights.tif
# Adding empty weight file: 0269_weights.tif
# Adding empty weight file: 0270_weights.tif
# Adding empty weight file: 0271_weights.tif
# Adding empty weight file: 0272_weights.tif
# Adding empty weight file: 0273_weights.tif
# Adding empty weight file: 0274_weights.tif
# Adding empty weight file: 0275_weights.tif
# Adding empty weight file: 0276_weights.tif
# Adding empty weight file: 0277_weights.tif
# Adding empty weight file: 0278_weights.tif
# Adding empty weight file: 0279_weights.tif
# Adding empty weight file: 0280_weights.tif
# Adding empty weight file: 0281_weights.tif
# Adding empty weight file: 0282_weights.tif
# Adding empty weight file: 0283_weights.tif
# Adding empty weight file: 0284_weights.tif
# Adding empty weight file: 0285_weights.tif
# Adding empty weight file: 0286_weights.tif
# Adding empty weight file: 0287_weights.tif
# Adding empty weight file: 0288_weights.tif
# Adding empty weight file: 0289_weights.tif
# Adding empty weight file: 0290_weights.tif
# Adding empty weight file: 0291_weights.tif
# Adding empty weight file: 0292_weights.tif
# Adding empty weight file: 0293_weights.tif
# Adding empty weight file: 0294_weights.tif
# Adding empty weight file: 0295_weights.tif
# Adding empty weight file: 0296_weights.tif
# Adding empty weight file: 0297_weights.tif
# Adding empty weight file: 0298_weights.tif
# Adding empty weight file: 0299_weights.tif
# Adding empty weight file: 0300_weights.tif
# Adding empty weight file: 0301_weights.tif
# Adding empty weight file: 0302_weights.tif
# Adding empty weight file: 0303_weights.tif
# Adding empty weight file: 0304_weights.tif
# Adding empty weight file: 0305_weights.tif
# Adding empty weight file: 0306_weights.tif
# Adding empty weight file: 0307_weights.tif
# Adding empty weight file: 0308_weights.tif
# Adding empty weight file: 0309_weights.tif
# Adding empty weight file: 0310_weights.tif
# Adding empty weight file: 0311_weights.tif
# Adding empty weight file: 0312_weights.tif
# Adding empty weight file: 0313_weights.tif
# Adding empty weight file: 0314_weights.tif
# Adding empty weight file: 0315_weights.tif
# Adding empty weight file: 0316_weights.tif
# Adding empty weight file: 0317_weights.tif
# Adding empty weight file: 0318_weights.tif
# Adding empty weight file: 0319_weights.tif
# Adding empty weight file: 0320_weights.tif
# Adding empty weight file: 0321_weights.tif
# Adding empty weight file: 0322_weights.tif
# Adding empty weight file: 0323_weights.tif
# Adding empty weight file: 0324_weights.tif
# Adding empty weight file: 0325_weights.tif
# Adding empty weight file: 0326_weights.tif
# Adding empty weight file: 0327_weights.tif
# Adding empty weight file: 0328_weights.tif
# Adding empty weight file: 0329_weights.tif
# Adding empty weight file: 0330_weights.tif
# Adding empty weight file: 0331_weights.tif
# Adding empty weight file: 0332_weights.tif
# Adding empty weight file: 0333_weights.tif
# Adding empty weight file: 0334_weights.tif
# Adding empty weight file: 0335_weights.tif
# Adding empty weight file: 0336_weights.tif
# Adding empty weight file: 0337_weights.tif
# Adding empty weight file: 0338_weights.tif
# Adding empty weight file: 0339_weights.tif
# Adding empty weight file: 0340_weights.tif
# Adding empty weight file: 0341_weights.tif
# Adding empty weight file: 0342_weights.tif
# Adding empty weight file: 0343_weights.tif
# Adding empty weight file: 0344_weights.tif
# Adding empty weight file: 0345_weights.tif
# Adding empty weight file: 0346_weights.tif
# Adding empty weight file: 0347_weights.tif
# Adding empty weight file: 0348_weights.tif
# Adding empty weight file: 0349_weights.tif
# Adding empty weight file: 0350_weights.tif
# Adding empty weight file: 0351_weights.tif
# Adding empty weight file: 0352_weights.tif
# Adding empty weight file: 0353_weights.tif
# Adding empty weight file: 0354_weights.tif
# Adding empty weight file: 0355_weights.tif
# Adding empty weight file: 0356_weights.tif
# Adding empty weight file: 0357_weights.tif
# Adding empty weight file: 0358_weights.tif
# Adding empty weight file: 0359_weights.tif
# Adding empty weight file: 0360_weights.tif
# Adding empty weight file: 0361_weights.tif
# Adding empty weight file: 0362_weights.tif
# Adding empty weight file: 0363_weights.tif
# Adding empty weight file: 0364_weights.tif
# Adding empty weight file: 0365_weights.tif
# Adding empty weight file: 0366_weights.tif
# Adding empty weight file: 0367_weights.tif
# Adding empty weight file: 0368_weights.tif
# Adding empty weight file: 0369_weights.tif
# Adding empty weight file: 0370_weights.tif
# Adding empty weight file: 0371_weights.tif
# Adding empty weight file: 0372_weights.tif
# Adding empty weight file: 0373_weights.tif
# Adding empty weight file: 0374_weights.tif
# Adding empty weight file: 0375_weights.tif
# Adding empty weight file: 0376_weights.tif
# Adding empty weight file: 0377_weights.tif
# Adding empty weight file: 0378_weights.tif
# Adding empty weight file: 0379_weights.tif
# Adding empty weight file: 0380_weights.tif
# Adding empty weight file: 0381_weights.tif
# Adding empty weight file: 0382_weights.tif
# Adding empty weight file: 0383_weights.tif
# Adding empty weight file: 0384_weights.tif
# Adding empty weight file: 0385_weights.tif
# Adding empty weight file: 0386_weights.tif
# Adding empty weight file: 0387_weights.tif
# Adding empty weight file: 0388_weights.tif
# Adding empty weight file: 0389_weights.tif
# Adding empty weight file: 0390_weights.tif
# Adding empty weight file: 0391_weights.tif
# Adding empty weight file: 0392_weights.tif
# Adding empty weight file: 0393_weights.tif
# Adding empty weight file: 0394_weights.tif
# Adding empty weight file: 0395_weights.tif
# Adding empty weight file: 0396_weights.tif
# Adding empty weight file: 0397_weights.tif
# Adding empty weight file: 0398_weights.tif
# Adding empty weight file: 0399_weights.tif
# Adding empty weight file: 0400_weights.tif
# Adding empty weight file: 0401_weights.tif
# Adding empty weight file: 0402_weights.tif
# Adding empty weight file: 0403_weights.tif
# Adding empty weight file: 0404_weights.tif
# Adding empty weight file: 0405_weights.tif
# Adding empty weight file: 0406_weights.tif
# Adding empty weight file: 0407_weights.tif
# Adding empty weight file: 0408_weights.tif
# Adding empty weight file: 0409_weights.tif
# Adding empty weight file: 0410_weights.tif
# Adding empty weight file: 0411_weights.tif
# Adding empty weight file: 0412_weights.tif
# Adding empty weight file: 0413_weights.tif
# Adding empty weight file: 0414_weights.tif
# Adding empty weight file: 0415_weights.tif
# Adding empty weight file: 0416_weights.tif
# Adding empty weight file: 0417_weights.tif
# Adding empty weight file: 0418_weights.tif
# Adding empty weight file: 0419_weights.tif
# Adding empty weight file: 0420_weights.tif
# Adding empty weight file: 0421_weights.tif
# Adding empty weight file: 0422_weights.tif
# Adding empty weight file: 0423_weights.tif
# Adding empty weight file: 0424_weights.tif
# Adding empty weight file: 0425_weights.tif
# Adding empty weight file: 0426_weights.tif
# Adding empty weight file: 0427_weights.tif
# Adding empty weight file: 0428_weights.tif
# Adding empty weight file: 0429_weights.tif
# Adding empty weight file: 0430_weights.tif
# Adding empty weight file: 0431_weights.tif
# Adding empty weight file: 0432_weights.tif
# Adding empty weight file: 0433_weights.tif
# Adding empty weight file: 0434_weights.tif
# Adding empty weight file: 0435_weights.tif
# Adding empty weight file: 0436_weights.tif
# Adding empty weight file: 0437_weights.tif
# Adding empty weight file: 0438_weights.tif
# Adding empty weight file: 0439_weights.tif
# Adding empty weight file: 0440_weights.tif
# Adding empty weight file: 0441_weights.tif
# Adding empty weight file: 0442_weights.tif
# Adding empty weight file: 0443_weights.tif
# Adding empty weight file: 0444_weights.tif
# Adding empty weight file: 0445_weights.tif
# Adding empty weight file: 0446_weights.tif
# Adding empty weight file: 0447_weights.tif
# Adding empty weight file: 0448_weights.tif
# Adding empty weight file: 0449_weights.tif
# Adding empty weight file: 0450_weights.tif
# Adding empty weight file: 0451_weights.tif
# Adding empty weight file: 0452_weights.tif
# Adding empty weight file: 0453_weights.tif
# Adding empty weight file: 0454_weights.tif
# Adding empty weight file: 0455_weights.tif
# Adding empty weight file: 0456_weights.tif
# Adding empty weight file: 0457_weights.tif
# Adding empty weight file: 0458_weights.tif
# Adding empty weight file: 0459_weights.tif
# Adding empty weight file: 0460_weights.tif
# Adding empty weight file: 0461_weights.tif
# Adding empty weight file: 0462_weights.tif
# Adding empty weight file: 0463_weights.tif
# Adding empty weight file: 0464_weights.tif
# Adding empty weight file: 0465_weights.tif
# Adding empty weight file: 0466_weights.tif
# Adding empty weight file: 0467_weights.tif
# Adding empty weight file: 0468_weights.tif
# Adding empty weight file: 0469_weights.tif
# Adding empty weight file: 0470_weights.tif
# Adding empty weight file: 0471_weights.tif
# Adding empty weight file: 0472_weights.tif
# Adding empty weight file: 0473_weights.tif
# Adding empty weight file: 0474_weights.tif
# Adding empty weight file: 0475_weights.tif
# Adding empty weight file: 0476_weights.tif
# Adding empty weight file: 0477_weights.tif
# Adding empty weight file: 0478_weights.tif
# Adding empty weight file: 0479_weights.tif
# Adding empty weight file: 0480_weights.tif
# Adding empty weight file: 0481_weights.tif
# Adding empty weight file: 0482_weights.tif
# Adding empty weight file: 0483_weights.tif
# Adding empty weight file: 0484_weights.tif
# Adding empty weight file: 0485_weights.tif
# Adding empty weight file: 0486_weights.tif
# Adding empty weight file: 0487_weights.tif
# Adding empty weight file: 0488_weights.tif
# Adding empty weight file: 0489_weights.tif
# Adding empty weight file: 0490_weights.tif
# Adding empty weight file: 0491_weights.tif
# Adding empty weight file: 0492_weights.tif
# Adding empty weight file: 0493_weights.tif
# Adding empty weight file: 0494_weights.tif
# Adding empty weight file: 0495_weights.tif
# Adding empty weight file: 0496_weights.tif
# Adding empty weight file: 0497_weights.tif
# Adding empty weight file: 0498_weights.tif
# Adding empty weight file: 0499_weights.tif
# Adding empty weight file: 0500_weights.tif
# Adding empty weight file: 0501_weights.tif
# Adding empty weight file: 0502_weights.tif
# Adding empty weight file: 0503_weights.tif
# Adding empty weight file: 0504_weights.tif
# Adding empty weight file: 0505_weights.tif
# Adding empty weight file: 0506_weights.tif
# Adding empty weight file: 0507_weights.tif
# Adding empty weight file: 0508_weights.tif
# Adding empty weight file: 0509_weights.tif
# Adding empty weight file: 0510_weights.tif
# Adding empty weight file: 0511_weights.tif
# Adding empty weight file: 0512_weights.tif
# Adding empty weight file: 0513_weights.tif
# Adding empty weight file: 0514_weights.tif
# Adding empty weight file: 0515_weights.tif
# Adding empty weight file: 0516_weights.tif
# Adding empty weight file: 0517_weights.tif
# Adding empty weight file: 0518_weights.tif
# Adding empty weight file: 0519_weights.tif
# Adding empty weight file: 0520_weights.tif
# Adding empty weight file: 0521_weights.tif
# Adding empty weight file: 0522_weights.tif
# Adding empty weight file: 0523_weights.tif
# Adding empty weight file: 0524_weights.tif
# Adding empty weight file: 0525_weights.tif
# Adding empty weight file: 0526_weights.tif
# Adding empty weight file: 0527_weights.tif
# Adding empty weight file: 0528_weights.tif
# Adding empty weight file: 0529_weights.tif
# Adding empty weight file: 0530_weights.tif
# Adding empty weight file: 0531_weights.tif
# Adding empty weight file: 0532_weights.tif
# Adding empty weight file: 0533_weights.tif
# Adding empty weight file: 0534_weights.tif
# Adding empty weight file: 0535_weights.tif
# Adding empty weight file: 0536_weights.tif
# Adding empty weight file: 0537_weights.tif
# Adding empty weight file: 0538_weights.tif
# Adding empty weight file: 0539_weights.tif
# Adding empty weight file: 0540_weights.tif
# Adding empty weight file: 0541_weights.tif
# Adding empty weight file: 0542_weights.tif
# Adding empty weight file: 0543_weights.tif
# Adding empty weight file: 0544_weights.tif
# Adding empty weight file: 0545_weights.tif
# Adding empty weight file: 0546_weights.tif
# Adding empty weight file: 0547_weights.tif
# Adding empty weight file: 0548_weights.tif
# Adding empty weight file: 0549_weights.tif
# Adding empty weight file: 0550_weights.tif
# Adding empty weight file: 0551_weights.tif
# Adding empty weight file: 0552_weights.tif
# Adding empty weight file: 0553_weights.tif
# Adding empty weight file: 0554_weights.tif
# Adding empty weight file: 0555_weights.tif
# Adding empty weight file: 0556_weights.tif
# Adding empty weight file: 0557_weights.tif
# Adding empty weight file: 0558_weights.tif
# Adding empty weight file: 0559_weights.tif
# Adding empty weight file: 0560_weights.tif
# Adding empty weight file: 0561_weights.tif
# Adding empty weight file: 0562_weights.tif
# Adding empty weight file: 0563_weights.tif
# Adding empty weight file: 0564_weights.tif
# Adding empty weight file: 0565_weights.tif
# Adding empty weight file: 0566_weights.tif
# Adding empty weight file: 0567_weights.tif
# Adding empty weight file: 0568_weights.tif
# Adding empty weight file: 0569_weights.tif
# Adding empty weight file: 0570_weights.tif
# Adding empty weight file: 0571_weights.tif
# Adding empty weight file: 0572_weights.tif
# Adding empty weight file: 0573_weights.tif
# Adding empty weight file: 0574_weights.tif
# Adding empty weight file: 0575_weights.tif
# Adding empty weight file: 0576_weights.tif
# Adding empty weight file: 0577_weights.tif
# Adding empty weight file: 0578_weights.tif
# Adding empty weight file: 0579_weights.tif
# Adding empty weight file: 0580_weights.tif
# Adding empty weight file: 0581_weights.tif
# Adding empty weight file: 0582_weights.tif
# Adding empty weight file: 0583_weights.tif
# Adding empty weight file: 0584_weights.tif
# Adding empty weight file: 0585_weights.tif
# Adding empty weight file: 0586_weights.tif
# Adding empty weight file: 0587_weights.tif
# Adding empty weight file: 0588_weights.tif
# Adding empty weight file: 0589_weights.tif
# Adding empty weight file: 0590_weights.tif
# Adding empty weight file: 0591_weights.tif
# Adding empty weight file: 0592_weights.tif
# Adding empty weight file: 0593_weights.tif
# Adding empty weight file: 0594_weights.tif
# Adding empty weight file: 0595_weights.tif
# Adding empty weight file: 0596_weights.tif
# Adding empty weight file: 0597_weights.tif
# Adding empty weight file: 0598_weights.tif
# Adding empty weight file: 0599_weights.tif
# Adding empty weight file: 0600_weights.tif
# Adding empty weight file: 0601_weights.tif
# Adding empty weight file: 0602_weights.tif
# Adding empty weight file: 0603_weights.tif
# Adding empty weight file: 0604_weights.tif
# Adding empty weight file: 0605_weights.tif
# Adding empty weight file: 0606_weights.tif
# Adding empty weight file: 0607_weights.tif
# Adding empty weight file: 0608_weights.tif
# Adding empty weight file: 0609_weights.tif
# Adding empty weight file: 0610_weights.tif
# Adding empty weight file: 0611_weights.tif
# Adding empty weight file: 0612_weights.tif
# Adding empty weight file: 0613_weights.tif
# Adding empty weight file: 0614_weights.tif
# Adding empty weight file: 0615_weights.tif
# Adding empty weight file: 0616_weights.tif
# Adding empty weight file: 0617_weights.tif
# Adding empty weight file: 0618_weights.tif
# Adding empty weight file: 0619_weights.tif
# Adding empty weight file: 0620_weights.tif
# Adding empty weight file: 0621_weights.tif
# Adding empty weight file: 0622_weights.tif
# Adding empty weight file: 0623_weights.tif
# Adding empty weight file: 0624_weights.tif
# Adding empty weight file: 0625_weights.tif
# Adding empty weight file: 0626_weights.tif
# Adding empty weight file: 0627_weights.tif
# Adding empty weight file: 0628_weights.tif
# Adding empty weight file: 0629_weights.tif
# Adding empty weight file: 0630_weights.tif
# Adding empty weight file: 0631_weights.tif
# Adding empty weight file: 0632_weights.tif
# Adding empty weight file: 0633_weights.tif
# Adding empty weight file: 0634_weights.tif
# Adding empty weight file: 0635_weights.tif
# Adding empty weight file: 0636_weights.tif
# Adding empty weight file: 0637_weights.tif
# Adding empty weight file: 0638_weights.tif
# Adding empty weight file: 0639_weights.tif
# Adding empty weight file: 0640_weights.tif
# Adding empty weight file: 0641_weights.tif
# Adding empty weight file: 0642_weights.tif
# Adding empty weight file: 0643_weights.tif
# Adding empty weight file: 0644_weights.tif
# Adding empty weight file: 0645_weights.tif
# Adding empty weight file: 0646_weights.tif
# Adding empty weight file: 0647_weights.tif
# Adding empty weight file: 0648_weights.tif
# Adding empty weight file: 0649_weights.tif
# Adding empty weight file: 0650_weights.tif
# Adding empty weight file: 0651_weights.tif
# Adding empty weight file: 0652_weights.tif
# Adding empty weight file: 0653_weights.tif
# Adding empty weight file: 0654_weights.tif
# Adding empty weight file: 0655_weights.tif
# Adding empty weight file: 0656_weights.tif
# Adding empty weight file: 0657_weights.tif
# Adding empty weight file: 0658_weights.tif
# Adding empty weight file: 0659_weights.tif
# Adding empty weight file: 0660_weights.tif
# Adding empty weight file: 0661_weights.tif
# Adding empty weight file: 0662_weights.tif
# Adding empty weight file: 0663_weights.tif
# Adding empty weight file: 0664_weights.tif
# Adding empty weight file: 0665_weights.tif
# Adding empty weight file: 0666_weights.tif
# Adding empty weight file: 0667_weights.tif
# Adding empty weight file: 0668_weights.tif
# Adding empty weight file: 0669_weights.tif
# Adding empty weight file: 0670_weights.tif
# Adding empty weight file: 0671_weights.tif
# Adding empty weight file: 0672_weights.tif
# Adding empty weight file: 0673_weights.tif
# Adding empty weight file: 0674_weights.tif
# Adding empty weight file: 0675_weights.tif
# Adding empty weight file: 0676_weights.tif
# Adding empty weight file: 0677_weights.tif
# Adding empty weight file: 0678_weights.tif
# Adding empty weight file: 0679_weights.tif
# Adding empty weight file: 0680_weights.tif
# Adding empty weight file: 0681_weights.tif
# Adding empty weight file: 0682_weights.tif
# Adding empty weight file: 0683_weights.tif
# Adding empty weight file: 0684_weights.tif
# Adding empty weight file: 0685_weights.tif
# Adding empty weight file: 0686_weights.tif
# Adding empty weight file: 0687_weights.tif
# Adding empty weight file: 0688_weights.tif
# Adding empty weight file: 0689_weights.tif
# Adding empty weight file: 0690_weights.tif
# Adding empty weight file: 0691_weights.tif
# Adding empty weight file: 0692_weights.tif
# Adding empty weight file: 0693_weights.tif
# Adding empty weight file: 0694_weights.tif
# Adding empty weight file: 0695_weights.tif
# Adding empty weight file: 0696_weights.tif
# Adding empty weight file: 0697_weights.tif
# Adding empty weight file: 0698_weights.tif
# Adding empty weight file: 0699_weights.tif
# Adding empty weight file: 0700_weights.tif
# Adding empty weight file: 0701_weights.tif
# Adding empty weight file: 0702_weights.tif
# Adding empty weight file: 0703_weights.tif
# Adding empty weight file: 0704_weights.tif
# Adding empty weight file: 0705_weights.tif
# Adding empty weight file: 0706_weights.tif
# Adding empty weight file: 0707_weights.tif
# Adding empty weight file: 0708_weights.tif
# Adding empty weight file: 0709_weights.tif
# Adding empty weight file: 0710_weights.tif
# Adding empty weight file: 0711_weights.tif
# Adding empty weight file: 0712_weights.tif
# Adding empty weight file: 0713_weights.tif
# Adding empty weight file: 0714_weights.tif
# Adding empty weight file: 0715_weights.tif
# Adding empty weight file: 0716_weights.tif
# Adding empty weight file: 0717_weights.tif
# Adding empty weight file: 0718_weights.tif
# Adding empty weight file: 0719_weights.tif
# Adding empty weight file: 0720_weights.tif
# Adding empty weight file: 0721_weights.tif
# Adding empty weight file: 0722_weights.tif
# Adding empty weight file: 0723_weights.tif
# Adding empty weight file: 0724_weights.tif
# Adding empty weight file: 0725_weights.tif
# Adding empty weight file: 0726_weights.tif
# Adding empty weight file: 0727_weights.tif
# Adding empty weight file: 0728_weights.tif
# Adding empty weight file: 0729_weights.tif
# Adding empty weight file: 0730_weights.tif
# Adding empty weight file: 0731_weights.tif
# Adding empty weight file: 0732_weights.tif
# Adding empty weight file: 0733_weights.tif
# Adding empty weight file: 0734_weights.tif
# Adding empty weight file: 0735_weights.tif
# Adding empty weight file: 0736_weights.tif
# Adding empty weight file: 0737_weights.tif
# Adding empty weight file: 0738_weights.tif
# Adding empty weight file: 0739_weights.tif
# Adding empty weight file: 0740_weights.tif
# Adding empty weight file: 0741_weights.tif
# Adding empty weight file: 0742_weights.tif
# Adding empty weight file: 0743_weights.tif
# Adding empty weight file: 0744_weights.tif
# Adding empty weight file: 0745_weights.tif
# Adding empty weight file: 0746_weights.tif
# Adding empty weight file: 0747_weights.tif
# Adding empty weight file: 0748_weights.tif
# Adding empty weight file: 0749_weights.tif
# Adding empty weight file: 0750_weights.tif
# Adding empty weight file: 0751_weights.tif
# Adding empty weight file: 0752_weights.tif
# Adding empty weight file: 0753_weights.tif
# Adding empty weight file: 0754_weights.tif
# Adding empty weight file: 0755_weights.tif
# Adding empty weight file: 0756_weights.tif
# Adding empty weight file: 0757_weights.tif
# Adding empty weight file: 0758_weights.tif
# Adding empty weight file: 0759_weights.tif
# Adding empty weight file: 0760_weights.tif
# Adding empty weight file: 0761_weights.tif
# Adding empty weight file: 0762_weights.tif
# Adding empty weight file: 0763_weights.tif
# Adding empty weight file: 0764_weights.tif
# Adding empty weight file: 0765_weights.tif
# Adding empty weight file: 0766_weights.tif
# Adding empty weight file: 0767_weights.tif
# Adding empty weight file: 0768_weights.tif
# Adding empty weight file: 0769_weights.tif
# Adding empty weight file: 0770_weights.tif
# Adding empty weight file: 0771_weights.tif
# Adding empty weight file: 0772_weights.tif
# Adding empty weight file: 0773_weights.tif
# Adding empty weight file: 0774_weights.tif
# Adding empty weight file: 0775_weights.tif
# Adding empty weight file: 0776_weights.tif
# Adding empty weight file: 0777_weights.tif
# Adding empty weight file: 0778_weights.tif
# Adding empty weight file: 0779_weights.tif
# Adding empty weight file: 0780_weights.tif
# Adding empty weight file: 0781_weights.tif
# Adding empty weight file: 0782_weights.tif
# Adding empty weight file: 0783_weights.tif
# Adding empty weight file: 0784_weights.tif
# Adding empty weight file: 0785_weights.tif
# Adding empty weight file: 0786_weights.tif
# Adding empty weight file: 0787_weights.tif
# Adding empty weight file: 0788_weights.tif
# Adding empty weight file: 0789_weights.tif
# Adding empty weight file: 0790_weights.tif
# Adding empty weight file: 0791_weights.tif
# Adding empty weight file: 0792_weights.tif
# Adding empty weight file: 0793_weights.tif
# Adding empty weight file: 0794_weights.tif
# Adding empty weight file: 0795_weights.tif
# Adding empty weight file: 0796_weights.tif
# Adding empty weight file: 0797_weights.tif
# Adding empty weight file: 0798_weights.tif
# Adding empty weight file: 0799_weights.tif
# Adding empty weight file: 0800_weights.tif
# Adding empty weight file: 0801_weights.tif
# Adding empty weight file: 0802_weights.tif
# Adding empty weight file: 0803_weights.tif
# Adding empty weight file: 0804_weights.tif
# Adding empty weight file: 0805_weights.tif
# Adding empty weight file: 0806_weights.tif
# Adding empty weight file: 0807_weights.tif
# Adding empty weight file: 0808_weights.tif
# Adding empty weight file: 0809_weights.tif
# Adding empty weight file: 0810_weights.tif
# Adding empty weight file: 0811_weights.tif
# Adding empty weight file: 0812_weights.tif
# Adding empty weight file: 0813_weights.tif
# Adding empty weight file: 0814_weights.tif
# Adding empty weight file: 0815_weights.tif
# Adding empty weight file: 0816_weights.tif
# Adding empty weight file: 0817_weights.tif
# Adding empty weight file: 0818_weights.tif
# Adding empty weight file: 0819_weights.tif
# Adding empty weight file: 0820_weights.tif
# Adding empty weight file: 0821_weights.tif
# Adding empty weight file: 0822_weights.tif
# Adding empty weight file: 0823_weights.tif
# Adding empty weight file: 0824_weights.tif
# Adding empty weight file: 0825_weights.tif
# Adding empty weight file: 0826_weights.tif
# Adding empty weight file: 0827_weights.tif
# Adding empty weight file: 0828_weights.tif
# Adding empty weight file: 0829_weights.tif
# Adding empty weight file: 0830_weights.tif
# Adding empty weight file: 0831_weights.tif
# Adding empty weight file: 0832_weights.tif
# Adding empty weight file: 0833_weights.tif
# Adding empty weight file: 0834_weights.tif
# Adding empty weight file: 0835_weights.tif
# Adding empty weight file: 0836_weights.tif
# Adding empty weight file: 0837_weights.tif
# Adding empty weight file: 0838_weights.tif
# Adding empty weight file: 0839_weights.tif
# Adding empty weight file: 0840_weights.tif
# Adding empty weight file: 0841_weights.tif
# Adding empty weight file: 0842_weights.tif
# Adding empty weight file: 0843_weights.tif
# Adding empty weight file: 0844_weights.tif
# Adding empty weight file: 0845_weights.tif
# Adding empty weight file: 0846_weights.tif
# Adding empty weight file: 0847_weights.tif
# Adding empty weight file: 0848_weights.tif
# Adding empty weight file: 0849_weights.tif
# Adding empty weight file: 0850_weights.tif
# Adding empty weight file: 0851_weights.tif
# Adding empty weight file: 0852_weights.tif
# Adding empty weight file: 0853_weights.tif
# Adding empty weight file: 0854_weights.tif
# Adding empty weight file: 0855_weights.tif
# Adding empty weight file: 0856_weights.tif
# Adding empty weight file: 0857_weights.tif
# Adding empty weight file: 0858_weights.tif
# Adding empty weight file: 0859_weights.tif
# Adding empty weight file: 0860_weights.tif
# Adding empty weight file: 0861_weights.tif
# Adding empty weight file: 0862_weights.tif
# Adding empty weight file: 0863_weights.tif
# Adding empty weight file: 0864_weights.tif
# Adding empty weight file: 0865_weights.tif
# Adding empty weight file: 0866_weights.tif
# Adding empty weight file: 0867_weights.tif
# Adding empty weight file: 0868_weights.tif
# Adding empty weight file: 0869_weights.tif
# Adding empty weight file: 0870_weights.tif
# Adding empty weight file: 0871_weights.tif
# Adding empty weight file: 0872_weights.tif
# Adding empty weight file: 0873_weights.tif
# Adding empty weight file: 0874_weights.tif
# Adding empty weight file: 0875_weights.tif
# Adding empty weight file: 0876_weights.tif
# Adding empty weight file: 0877_weights.tif
# Adding empty weight file: 0878_weights.tif
# Adding empty weight file: 0879_weights.tif
# Adding empty weight file: 0880_weights.tif
# Adding empty weight file: 0881_weights.tif
# Adding empty weight file: 0882_weights.tif
# Adding empty weight file: 0883_weights.tif
# Adding empty weight file: 0884_weights.tif
# Adding empty weight file: 0885_weights.tif
# Adding empty weight file: 0886_weights.tif
# Adding empty weight file: 0887_weights.tif
# Adding empty weight file: 0888_weights.tif
# Adding empty weight file: 0889_weights.tif
# Adding empty weight file: 0890_weights.tif
# Adding empty weight file: 0891_weights.tif
# Adding empty weight file: 0892_weights.tif
# Adding empty weight file: 0893_weights.tif
# Adding empty weight file: 0894_weights.tif
# Adding empty weight file: 0895_weights.tif
# Adding empty weight file: 0896_weights.tif
# Adding empty weight file: 0897_weights.tif
# Adding empty weight file: 0898_weights.tif
# Adding empty weight file: 0899_weights.tif
# Adding empty weight file: 0900_weights.tif
# Adding empty weight file: 0901_weights.tif
# Adding empty weight file: 0902_weights.tif
# Adding empty weight file: 0903_weights.tif
# Adding empty weight file: 0904_weights.tif
# Adding empty weight file: 0905_weights.tif
# Adding empty weight file: 0906_weights.tif
# Adding empty weight file: 0907_weights.tif
# Adding empty weight file: 0908_weights.tif
# Adding empty weight file: 0909_weights.tif
# Adding empty weight file: 0910_weights.tif
# Adding empty weight file: 0911_weights.tif
# Adding empty weight file: 0912_weights.tif
# Adding empty weight file: 0913_weights.tif
# Adding empty weight file: 0914_weights.tif
# Adding empty weight file: 0915_weights.tif
# Adding empty weight file: 0916_weights.tif
# Adding empty weight file: 0917_weights.tif
# Adding empty weight file: 0918_weights.tif
# Adding empty weight file: 0919_weights.tif
# Adding empty weight file: 0920_weights.tif
# Adding empty weight file: 0921_weights.tif
# Adding empty weight file: 0922_weights.tif
# Adding empty weight file: 0923_weights.tif
# Adding empty weight file: 0924_weights.tif
# Adding empty weight file: 0925_weights.tif
# Adding empty weight file: 0926_weights.tif
# Adding empty weight file: 0927_weights.tif
# Adding empty weight file: 0928_weights.tif
# Adding empty weight file: 0929_weights.tif
# Adding empty weight file: 0930_weights.tif
# Adding empty weight file: 0931_weights.tif
# Adding empty weight file: 0932_weights.tif
# Adding empty weight file: 0933_weights.tif
# Adding empty weight file: 0934_weights.tif
# Adding empty weight file: 0935_weights.tif
# Adding empty weight file: 0936_weights.tif
# Adding empty weight file: 0937_weights.tif
# Adding empty weight file: 0938_weights.tif
# Adding empty weight file: 0939_weights.tif
# Adding empty weight file: 0940_weights.tif
# Adding empty weight file: 0941_weights.tif
# Adding empty weight file: 0942_weights.tif
# Adding empty weight file: 0943_weights.tif
# Adding empty weight file: 0944_weights.tif
# Adding empty weight file: 0945_weights.tif
# Adding empty weight file: 0946_weights.tif
# Adding empty weight file: 0947_weights.tif
# Adding empty weight file: 0948_weights.tif
# Adding empty weight file: 0949_weights.tif
# Adding empty weight file: 0950_weights.tif
# Adding empty weight file: 0951_weights.tif
# Adding empty weight file: 0952_weights.tif
# Adding empty weight file: 0953_weights.tif
# Adding empty weight file: 0954_weights.tif
# Adding empty weight file: 0955_weights.tif
# Adding empty weight file: 0956_weights.tif
# Adding empty weight file: 0957_weights.tif
# Adding empty weight file: 0958_weights.tif
# Adding empty weight file: 0959_weights.tif
# Adding empty weight file: 0960_weights.tif
# Adding empty weight file: 0961_weights.tif
# Adding empty weight file: 0962_weights.tif
# Adding empty weight file: 0963_weights.tif
# Adding empty weight file: 0964_weights.tif
# Adding empty weight file: 0965_weights.tif
# Adding empty weight file: 0966_weights.tif
# Adding empty weight file: 0967_weights.tif
# Adding empty weight file: 0968_weights.tif
# Adding empty weight file: 0969_weights.tif
# Adding empty weight file: 0970_weights.tif
# Adding empty weight file: 0971_weights.tif
# Adding empty weight file: 0972_weights.tif
# Adding empty weight file: 0973_weights.tif
# Adding empty weight file: 0974_weights.tif
# Adding empty weight file: 0975_weights.tif
# Adding empty weight file: 0976_weights.tif
# Adding empty weight file: 0977_weights.tif
# Adding empty weight file: 0978_weights.tif
# Adding empty weight file: 0979_weights.tif
# Adding empty weight file: 0980_weights.tif
# Adding empty weight file: 0981_weights.tif
# Adding empty weight file: 0982_weights.tif
# Adding empty weight file: 0983_weights.tif
# Adding empty weight file: 0984_weights.tif
# Adding empty weight file: 0985_weights.tif
# Adding empty weight file: 0986_weights.tif
# Adding empty weight file: 0987_weights.tif
# Adding empty weight file: 0988_weights.tif
# Adding empty weight file: 0989_weights.tif
# Adding empty weight file: 0990_weights.tif
# Adding empty weight file: 0991_weights.tif
# Adding empty weight file: 0992_weights.tif
# Adding empty weight file: 0993_weights.tif
# Adding empty weight file: 0994_weights.tif
# Adding empty weight file: 0995_weights.tif
# Adding empty weight file: 0996_weights.tif
# Adding empty weight file: 0997_weights.tif
# Adding empty weight file: 0998_weights.tif
# Adding empty weight file: 0999_weights.tif
# Adding empty weight file: 1000_weights.tif
# Adding empty weight file: 1001_weights.tif
# Adding empty weight file: 1002_weights.tif
# Adding empty weight file: 1003_weights.tif
# Adding empty weight file: 1004_weights.tif
# Adding empty weight file: 1005_weights.tif
# Adding empty weight file: 1006_weights.tif
# Adding empty weight file: 1007_weights.tif
# Adding empty weight file: 1008_weights.tif
# Adding empty weight file: 1009_weights.tif
# Adding empty weight file: 1010_weights.tif
# Adding empty weight file: 1011_weights.tif
# Adding empty weight file: 1012_weights.tif
# Adding empty weight file: 1013_weights.tif
# Adding empty weight file: 1014_weights.tif
# Adding empty weight file: 1015_weights.tif
# Adding empty weight file: 1016_weights.tif
# Adding empty weight file: 1017_weights.tif
# Adding empty weight file: 1018_weights.tif
# Adding empty weight file: 1019_weights.tif
# Adding empty weight file: 1020_weights.tif
# Adding empty weight file: 1021_weights.tif
# Adding empty weight file: 1022_weights.tif
# Adding empty weight file: 1023_weights.tif
# Adding empty weight file: 1024_weights.tif
# Adding empty weight file: 1025_weights.tif
# Adding empty weight file: 1026_weights.tif
# Adding empty weight file: 1027_weights.tif
# Adding empty weight file: 1028_weights.tif
# Adding empty weight file: 1029_weights.tif
# Adding empty weight file: 1030_weights.tif
# Adding empty weight file: 1031_weights.tif
# Adding empty weight file: 1032_weights.tif
# Adding empty weight file: 1033_weights.tif
# Adding empty weight file: 1034_weights.tif
# Adding empty weight file: 1035_weights.tif
# Adding empty weight file: 1036_weights.tif
# Adding empty weight file: 1037_weights.tif
# Adding empty weight file: 1038_weights.tif
# Adding empty weight file: 1039_weights.tif
# Adding empty weight file: 1040_weights.tif
# Adding empty weight file: 1041_weights.tif
# Adding empty weight file: 1042_weights.tif
# Adding empty weight file: 1043_weights.tif
# Adding empty weight file: 1044_weights.tif
# Adding empty weight file: 1045_weights.tif
# Adding empty weight file: 1046_weights.tif
# Adding empty weight file: 1047_weights.tif
# Adding empty weight file: 1048_weights.tif
# Adding empty weight file: 1049_weights.tif
# Adding empty weight file: 1050_weights.tif
# Adding empty weight file: 1051_weights.tif
# Adding empty weight file: 1052_weights.tif
# Adding empty weight file: 1053_weights.tif
# Adding empty weight file: 1054_weights.tif
# Adding empty weight file: 1055_weights.tif
# Adding empty weight file: 1056_weights.tif
# Adding empty weight file: 1057_weights.tif
# Adding empty weight file: 1058_weights.tif
# Adding empty weight file: 1059_weights.tif
# Adding empty weight file: 1060_weights.tif
# Adding empty weight file: 1061_weights.tif
# Adding empty weight file: 1062_weights.tif
# Adding empty weight file: 1063_weights.tif
# Adding empty weight file: 1064_weights.tif
# Adding empty weight file: 1065_weights.tif
# Adding empty weight file: 1066_weights.tif
# Adding empty weight file: 1067_weights.tif
# Adding empty weight file: 1068_weights.tif
# Adding empty weight file: 1069_weights.tif
# Adding empty weight file: 1070_weights.tif
# Adding empty weight file: 1071_weights.tif
# Adding empty weight file: 1072_weights.tif
# Adding empty weight file: 1073_weights.tif
# Adding empty weight file: 1074_weights.tif
# Adding empty weight file: 1075_weights.tif
# Adding empty weight file: 1076_weights.tif
# Adding empty weight file: 1077_weights.tif
# Adding empty weight file: 1078_weights.tif
# Adding empty weight file: 1079_weights.tif
# Adding empty weight file: 1080_weights.tif
# Adding empty weight file: 1081_weights.tif
# Adding empty weight file: 1082_weights.tif
# Adding empty weight file: 1083_weights.tif
# Adding empty weight file: 1084_weights.tif
# Adding empty weight file: 1085_weights.tif
# Adding empty weight file: 1086_weights.tif
# Adding empty weight file: 1087_weights.tif
# Adding empty weight file: 1088_weights.tif
# Adding empty weight file: 1089_weights.tif
# Adding empty weight file: 1090_weights.tif
# Adding empty weight file: 1091_weights.tif
# Adding empty weight file: 1092_weights.tif
# Channels.MASK set1/labels/0000_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0001_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0002_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0003_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0004_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0005_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0006_mask.tif.modified.tif (1024, 1024) uint8
# ...
# Channels.RFP set1/rfp/0803_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0804_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0805_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0806_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0807_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0808_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0809_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0810_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0811_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0812_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0813_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0814_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0815_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0816_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0817_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0818_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0819_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0820_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0821_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0822_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0823_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0824_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0825_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0826_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0827_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0828_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0829_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0830_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0831_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0832_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0833_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0834_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0835_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0836_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0837_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0838_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0839_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0840_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0841_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0842_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0843_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0844_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0845_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0846_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0847_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0848_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0849_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0850_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0851_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0852_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0853_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0854_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0855_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0856_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0857_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0858_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0859_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0860_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0861_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0862_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0863_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0864_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0865_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0866_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0867_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0868_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0869_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0870_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0871_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0872_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0873_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0874_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0875_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0876_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0877_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0878_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0879_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0880_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0881_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0882_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0883_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0884_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0885_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0886_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0887_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0888_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0889_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0890_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0891_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0892_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0893_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0894_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0895_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0896_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0897_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0898_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0899_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0900_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0901_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0902_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0903_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0904_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0905_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0906_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0907_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0908_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0909_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0910_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0911_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0912_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0913_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0914_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0915_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0916_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0917_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0918_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0919_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0920_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0921_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0922_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0923_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0924_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0925_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0926_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0927_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0928_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0929_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0930_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0931_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0932_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0933_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0934_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0935_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0936_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0937_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0938_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0939_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0940_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0941_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0942_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0943_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0944_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0945_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0946_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0947_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0948_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0949_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0950_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0951_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0952_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0953_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0954_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0955_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0956_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0957_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0958_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0959_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0960_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0961_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0962_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0963_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0964_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0965_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0966_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0967_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0968_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0969_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0970_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0971_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0972_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0973_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0974_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0975_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0976_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0977_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0978_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0979_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0980_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0981_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0982_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0983_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0984_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0985_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0986_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0987_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0988_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0989_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0990_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0991_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0992_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0993_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0994_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0995_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0996_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0997_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0998_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/0999_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1000_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1001_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1002_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1003_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1004_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1005_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1006_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1007_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1008_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1009_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1010_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1011_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1012_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1013_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1014_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1015_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1016_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1017_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1018_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1019_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1020_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1021_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1022_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1023_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1024_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1025_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1026_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1027_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1028_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1029_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1030_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1031_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1032_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1033_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1034_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1035_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1036_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1037_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1038_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1039_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1040_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1041_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1042_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1043_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1044_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1045_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1046_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1047_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1048_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1049_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1050_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1051_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1052_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1053_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1054_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1055_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1056_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1057_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1058_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1059_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1060_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1061_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1062_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1063_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1064_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1065_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1066_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1067_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1068_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1069_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1070_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1071_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1072_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1073_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1074_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1075_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1076_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1077_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1078_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1079_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1080_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1081_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1082_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1083_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1084_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1085_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1086_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1087_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1088_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1089_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1090_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1091_rfp.tif (1024, 1024) uint16
# Channels.RFP set1/rfp/1092_rfp.tif (1024, 1024) uint16

# %%
def normalize_images(stack):
    normed = stack.astype(np.float32)
    
    for i in range(stack.shape[0]):
        # normed[i,...] = (normed[i,...]-np.mean(normed[i,...])) / np.std(normed[i,...])
        c = normed[i,...]
        p_lo = np.percentile(c,5)
        p_hi = np.percentile(c,99)
        normed[i,...] = np.clip((c - p_lo) / p_hi, 0., 1.)
    return normed

# %%
def bounding_boxes(seg):
    lbl, nlbl = ndimage.label(seg)
    class_label, _, minxy, maxxy = ndimage.extrema(seg, lbl, index=np.arange(1, nlbl+1))
    return class_label, minxy, maxxy

# %%
seg = np.zeros(data[channels[0]]['data'].shape, dtype=np.uint8)
mask = data[Channels.MASK]['data']
if mask.ndim == 3:
    seg = mask > 0
elif mask.ndim == 4:
    seg[mask[:,0,...]>0] = 1
    seg[mask[:,1,...]>0] = 2

# %%
def convert_to_mask(labels, unique_labels=range(1,len(channels)+1)):
    print(unique_labels)
    seg = np.zeros((len(unique_labels),)+labels.shape, dtype=np.uint8)
    for i,l in enumerate(unique_labels):
        seg[i,...] = labels==l
    return np.squeeze(seg)

# %%
def save_labels(viewer):
    # get the current image 
    current_slice = viewer.layers[viewer.active_layer].coordinates[0]
    source_set = data[Channels.MASK]['sets'][current_slice]
    source_file = data[Channels.MASK]['files'][current_slice]
    source_fn = os.path.join(source_set, 'labels', source_file)

    # get the current layer
    current_labels = viewer.layers['labels'].data[current_slice,...]
    current_mask = convert_to_mask(current_labels)

    # write out the modified segmentation mask
    new_file = os.path.join(DATA_PATH, source_fn+'.modified.tif')
    print(new_file)
    io.imsave(new_file, current_mask[0].astype('uint8'))

    print(current_slice, current_labels.shape, new_file)

# %%
def save_all_labels(viewer):
        # get the current image 
    current_slice = viewer.layers[viewer.active_layer].coordinates[0]
    #current_slice = viewer.layers[viewer.active_layer].coordinates[1] # prints the x coord
    
    source_set = data[Channels.MASK]['sets'][current_slice]
    source_file = data[Channels.MASK]['files'][current_slice]
    source_fn = os.path.join(source_set, 'labels', source_file)

    # get the current layer
    current_labels = viewer.layers['labels'].data[current_slice,...]
    current_mask = convert_to_mask(current_labels)
    
    for i in range(viewer.layers['labels'].data.shape[0]):
        current_slice = i
        
        source_set = data[Channels.MASK]['sets'][current_slice]
        source_file = data[Channels.MASK]['files'][current_slice]
        source_fn = os.path.join(source_set, 'labels', source_file)
        
        current_labels = viewer.layers['labels'].data[current_slice,...]
        current_mask = convert_to_mask(current_labels)
        
        new_file = os.path.join(DATA_PATH, source_fn+'.modified.tif')

        io.imsave(new_file, current_mask[0].astype('uint8'))

        print(current_slice, current_labels.shape, new_file)

# %%
# weightmaps = np.zeros((seg.shape), dtype=np.float32)

def calculate_weightmaps(viewer, w0=WEIGHT_AMPLITUDE, current_slice=0):
    # get the current layer and make it binary
    mask = viewer.layers['labels'].data[current_slice,...].astype(np.bool)
    
    # label the image 
    labelled, n_labels = ndimage.label(mask)
    #print(n_labels)
    weight_mask = np.zeros(mask.shape, dtype=np.float32)
    for i in range(1,n_labels+1):
        cell = labelled == i
        not_cell = np.logical_xor(cell, mask) #np.logical_and(labelled != i, labelled > 0)
        mask_diff = gaussian_filter(cell.astype(np.float32), sigma=5) * gaussian_filter(not_cell.astype(np.float32), sigma=5)
        weight_mask += mask_diff

    wmap = w0*weight_mask #* wmap
    
    # normalize it
    wmap += 1.   
    wmap[mask] = 1.
      
    viewer.layers['weightmaps'].data[current_slice,...] = wmap.astype(np.float32)
    viewer.layers['weightmaps'].contrast_limits = (np.min(wmap), np.max(wmap))
    viewer.layers['weightmaps'].visible = True
    
    return wmap

# %%
# secondary weighting = weightmap * weightmask
# purpose is to create a secondary weightmap that can be used to tell the network to focus/ignore on user-selected ROIs

def calculate_custom_weightmap(viewer, current_slice=0):
    
    if "custom weightmap" not in str(viewer.layers): #this checks if the custom weightmap layer exists, and if it doesnt it creates one for it
        cust_wmap = data[Channels.WEIGHTS]['data']
        viewer.add_image(cust_wmap, name='custom weightmap', colormap='plasma', visible=False)
    
    w_mask = viewer.layers['weightmask'].data[current_slice,...].astype(np.bool)
    w_map =  viewer.layers['weightmaps'].data[current_slice,...]   
    cust_wmap = w_map*w_mask
  
    viewer.layers['custom weightmap'].data[current_slice,...] = cust_wmap.astype(np.float32) # need this line to 
    viewer.layers['custom weightmap'].contrast_limits = (np.min(cust_wmap), np.max(cust_wmap))
    viewer.layers['custom weightmap'].visible = True
    
    return cust_wmap

# %%
def grow_shrink_label(viewer, grow=True, n_iter=1): #by editing the number of iterations i can edit the size of growshrink
    current_slice = viewer.layers[viewer.active_layer].coordinates[0]
    current_labels = viewer.layers['labels'].data[current_slice,...] #label as in image
            
    cursor_coords = [int(p) for p in viewer.layers[viewer.active_layer].position]
    labelled, _ = ndimage.label(current_labels.astype(np.bool)) #each obj in label image is labelled
    real_label = current_labels[cursor_coords[0], cursor_coords[1]] #xy cursor coords in current label image
    
    if real_label < 1: return
    
    mask = labelled == labelled[cursor_coords[0], cursor_coords[1]] #assigning mask as labelled image with only xy of specific cell
    if grow:
        mask = ndimage.morphology.binary_dilation(mask, iterations=n_iter)   
    else:
        current_labels[mask] = 0
        mask = ndimage.morphology.binary_erosion(mask, iterations=n_iter)
    current_labels[mask] = real_label
    viewer.layers['labels'].data[current_slice,...] = current_labels
    viewer.layers['labels']._set_view_slice()

# %%
def count_cells(viewer):
    current_slice = viewer.layers[viewer.active_layer].coordinates[0]
    mask = viewer.layers['labels'].data[current_slice,...].astype(np.bool) 
    labelled, n_labels = ndimage.label(mask)
       
    stat_file = os.path.join(DATA_PATH, 'stats.csv')
    
    i=0
    df=pd.DataFrame(data=[0], index=[i], columns=['number of cells'])
    
    for i in range(viewer.layers['labels'].data.shape[0]):
        current_slice = i
        mask = viewer.layers['labels'].data[current_slice,...].astype(np.bool) 
        labelled, n_labels = ndimage.label(mask)
        
        
            
        df.loc[i] = n_labels
        df.to_csv(stat_file, index=False)
    print(df)

# %%
def measure(viewer): #for single cell trajectories, add another iterative loop when wanting all cell trajectories
    current_slice = viewer.layers[viewer.active_layer].coordinates[0]
    mask = viewer.layers['labels'].data[current_slice,...].astype(np.bool) 
    labelled, n_labels = ndimage.label(mask)
    for s in sets:
        dirName = os.path.join(DATA_PATH, s, 'results')
        try:
            # Create target Directory
            os.mkdir(dirName)
            print("Directory " , dirName ,  " Created ") 
        except FileExistsError:
            print("Directory " , dirName ,  " already exists")
    
        stat_file_dir = os.path.join(dirName, 'image_numbers_' + str(INDEX_OF_IMAGES))
        
        try:
            # Create target Directory
            os.mkdir(stat_file_dir)
            print("Directory " , stat_file_dir ,  " Created ") 
        except FileExistsError:
            print("Directory " , stat_file_dir ,  " already exists")
        os.mkdir()
        stat_file = os.path.join(stat_file_dir, 'stats.csv')
    
        i=0
        df = pd.DataFrame([], index=[i], columns=['GFP Intensity', 'RFP Intensity', 'Phase Intensity', 'Area', 'x','y']) #is this assignment of df correct? or does it overwrite "count_cells" above

        for i in range(viewer.layers['labels'].data.shape[0]):
            current_slice = i
            mask = viewer.layers['labels'].data[current_slice,...].astype(np.bool) 
            labelled, n_labels = ndimage.label(mask)

            gfp = viewer.layers['GFP'].data[current_slice,...]
            gfp_pix_value = ndimage.sum(gfp, labelled, 1) 
            #need way of linking labelled cell identities to tracks --> centroid?

            rfp = viewer.layers['RFP'].data[current_slice,...]
            rfp_pix_value = ndimage.sum(rfp, labelled, 1)

            phase = viewer.layers['Phase'].data[current_slice,...]
            phase_pix_value = ndimage.sum(phase, labelled, 1) # == ndimage.sum(mask*phase)

            df.loc[i,'GFP Intensity'] = gfp_pix_value 
            df.loc[i,'RFP Intensity'] = rfp_pix_value
            df.loc[i,'Phase Intensity'] = phase_pix_value 
            df.loc[i,'Area'] = ndimage.sum(mask)
            #df.loc[i,'Max'] =  ndimage.maximum(phase, labelled)

            centroid = ndimage.measurements.center_of_mass(mask)
            y = centroid[0]
            x = centroid[1]
            df.loc[i,'x'] = format(x, '.2f')
            df.loc[i,'y'] = format(y, '.2f')

            df.to_csv(stat_file, index=False)
        print(df)
        print('2468-never-too-late, I counted all them cells THANK U')

# %%
def fill_holes(viewer):
    current_slice = viewer.layers[viewer.active_layer].coordinates[0]
    current_labels = viewer.layers['labels'].data[current_slice,...] #label as in image
            
    cursor_coords = [int(p) for p in viewer.layers[viewer.active_layer].position]
    labelled, _ = ndimage.label(current_labels.astype(np.bool)) #each obj in label image is labelled
    real_label = current_labels[cursor_coords[0], cursor_coords[1]] #xy cursor coords in current label image
    
    if real_label < 1: return
    
    mask = labelled == labelled[cursor_coords[0], cursor_coords[1]] #assigning mask as labelled image with only xy of specific cell
    mask = ndimage.morphology.binary_fill_holes(mask) 
    current_labels[mask] = real_label
    viewer.layers['labels'].data[current_slice,...] = current_labels
    viewer.layers['labels']._set_view_slice()

# %%
def single_cell_mask(viewer):  #by editing the number of iterations i can edit the size of growshrink
    # get the current image 
    current_slice = viewer.layers[viewer.active_layer].coordinates[0]
    current_labels = viewer.layers['labels'].data[current_slice,...] #label as in image
    
        
    cursor_coords = [int(p) for p in viewer.layers[viewer.active_layer].position]
    labelled, _ = ndimage.label(current_labels.astype(np.bool)) #each obj in label image is labelled
    real_label = current_labels[cursor_coords[0], cursor_coords[1]] #xy cursor coords in current label image
    
    if real_label < 1: return
    
    mask = labelled == labelled[cursor_coords[0], cursor_coords[1]] #assigning mask as labelled image with only xy of specific cell
    
    current_labels = mask    
    viewer.layers['labels'].data[current_slice,...] = current_labels
    viewer.layers['labels']._set_view_slice()

# %%
def fluorescent_noise(viewer):
    pth = DATA_PATH
    for s in sets:
        #label_files = [f for f in os.listdir(l_root) if f.endswith('.tif')]
        l_root = os.path.join(pth, s, 'labels')
        label_files = [f for f in os.listdir(l_root) if f.endswith('.tif')]
        #add input for gfp and rfp
        channels = [Channels[c.upper()] for c in INCOMPLETE_CHANNELS]
        incomplete_files = {k:{'files':[], 'data':[], 'sets':[], 'path':[]} for k in channels} #need to add something like this to include Channels.GFP etc in files[channels]        
        files.update(incomplete_files) #merging two dicts to create complete file dict
        for channel in channels:
                #if cfiles channel.name.lower dir doesnt contain gfp or rfp then add option to create noise data,
                channel_dir = os.path.join(pth, s, channel.name.lower())            
                if os.path.exists(channel_dir): #if fluor/phase channels exist, continue as norm
                    cfiles = [fnfmt(l, channel.name.lower()) for l in label_files]                  
                    files[channel]['path'] += [s+'/'+channel.name.lower()+'/'+f for f in cfiles]
                    files[channel]['files'] += cfiles #filenames
                    files[channel]['data'] += [io.imread(os.path.join(pth, s, channel.name.lower(), f)) for f in cfiles] #actualdata
                    files[channel]['sets'] += [s] * len(label_files)
                    
                else: #if fluor ch missing then create one and fill it with noise - 
                    os.mkdir(channel_dir) #create fl ch dir
                    cfiles = [fnfmt(l, channel.name.lower()) for l in label_files]
                    files[channel]['path'] += [s+'/'+channel.name.lower()+'/'+f for f in cfiles]
                    files[channel]['files'] += cfiles #filenames 
                    files[channel]['sets'] += [s] * len(label_files)
                    
                    for f in cfiles:
                        print(f'Adding gaussian noise fluorescence file: {f}')             
                        #shape = [files[channels[0]]['data'][0].shape]
                        random = np.random.normal(loc=((2^32)/2), scale=((2^32)/2), size=shape) #(1024,1024)) what is the stdev of an 8bit image?
                        ### need to check if this is really the best way of generating a random image
                        random_path = os.path.join(channel_dir, f)
                        io.imsave(random_path, random.astype(np.float32))
                                            
                    files[channel]['data'] += [io.imread(os.path.join(pth, s, channel.name.lower(), f)) for f in cfiles] #reads image from disk and adds it to dict 
                                       
    print("I AM DONE, THANK YOU VERY MUCH")

# %%
# start napari
with napari.gui_qt():
    viewer = napari.Viewer()
    
    if Channels.GFP in data:
        #gfp = normalize_images(data[Channels.GFP]['data'])
        gfp = data[Channels.GFP]['data']
        viewer.add_image(gfp, name='GFP', colormap='green')#, contrast_limits=(0.,1.))
        
    if Channels.RFP in data:
        #rfp = normalize_images(data[Channels.RFP]['data'])
        rfp = data[Channels.RFP]['data']
        viewer.add_image(rfp, name='RFP', colormap='magenta')#, contrast_limits=(0.,1.))
        viewer.layers['RFP'].blending = 'additive'
        
    if Channels.PHASE in data:
        #phase = normalize_images(data[Channels.PHASE]['data'])
        phase = data[Channels.PHASE]['data']
        viewer.add_image(phase, name='Phase', colormap='gray')
    
    if Channels.WEIGHTS in data:
        weightmaps = data[Channels.WEIGHTS]['data']
        viewer.add_image(weightmaps, name='weightmaps', colormap='plasma', visible=False)
        
    """if Channels.WEIGHTS in data:
        cust_wmap = data[Channels.WEIGHTS]['data']
        viewer.add_image(cust_wmap, name='custom weightmap', colormap='plasma', visible=False)"""
    
    viewer.add_labels(seg, name='labels')
    viewer.layers['labels'].opacity = 0.4
    viewer.layers['weightmaps'].blending = 'additive'
    
    weight_mask = np.ones(data[Channels.WEIGHTS]['data'].shape, dtype=np.uint8)
    #cust_wmap = np.ones(data[Channels.WEIGHTS]['data'].shape, dtype=np.uint8)
    viewer.add_labels(weight_mask, name='weightmask', visible=False)
    #viewer.add_image(cust_wmap, name='custom weightmap', colormap='plasma', visible=False)

    @viewer.bind_key('g') #try capitalising this bind key to avoid accidental pressing
    def k_fluorescent_noise(viewer):
        print("Creating simulated fluorescence channels with gaussian noise")
        fluorescent_noise(viewer) 
            
    @viewer.bind_key('/') #double command
    def k_save_labels(viewer):
        save_labels(viewer)  #need to change the (viewer) bit to save all images   
        
    @viewer.bind_key('s')
    def k_save_all_labels(viewer):
        save_all_labels(viewer)
        
    @viewer.bind_key('n')
    def k_count_cells(viewer):
        count_cells(viewer)
        
    @viewer.bind_key('m')
    def k_measure(viewer):
        measure(viewer)
        
    @viewer.bind_key('w')
    def k_calculate_weightmaps(viewer):
        current_slice = viewer.layers[viewer.active_layer].coordinates[0]
        calculate_weightmaps(viewer, current_slice=current_slice)
        ## calculate cust_ here?
        
    @viewer.bind_key('q')
    def k_calculate_custom_weightmap(viewer):
        current_slice = viewer.layers[viewer.active_layer].coordinates[0]
        calculate_custom_weightmap(viewer, current_slice=current_slice)
        
    @viewer.bind_key('<')
    def k_shrink_label(viewer):
        print('shrink label')
        grow_shrink_label(viewer, grow=False)
    
    @viewer.bind_key('>') 
    def k_grow_label(viewer):
        print('grow label')
        grow_shrink_label(viewer, grow=True)
        
    @viewer.bind_key('0') #clear @viewer.bind_key('c')
    def k_single_cell(viewer):
        print('select cell')
        single_cell_mask(viewer)
        
    @viewer.bind_key('c') #clear @viewer.bind_key('c')
    def k_single_cell(viewer):
        print('select cell')
        single_cell_mask(viewer)
        
    @viewer.bind_key('h') #fill holes in cell masks
    def k_fill_holes(viewer):
        print('filling holes in cell mask')
        fill_holes(viewer) 
    
    @viewer.bind_key('o')
    def k_output(viewer):
        print('Output all with metadata')
                
        for i in range(viewer.layers['weightmaps'].data.shape[0]):
            
            if np.sum(viewer.layers['weightmaps'].data[i,...]) == 0: # get rid of this condition to calculate weightmaps afresh regardless?
                print(f'Weightmap {i} is empty. Calculating...')
                wmap = calculate_weightmaps(viewer, current_slice=i)
                weight_folder = os.path.join(DATA_PATH, data[Channels.WEIGHTS]['sets'][i], 'weights')
                weight_fn = data[Channels.WEIGHTS]['files'][i]
                print(weight_folder, weight_fn)
                make_folder(weight_folder)
                io.imsave(os.path.join(weight_folder, weight_fn), wmap.astype(np.float32))
          
                #write out cust_weight_map too
                
                cust_wmap = calculate_custom_weightmap(viewer, current_slice=i)
                cust_weight_folder = os.path.join(DATA_PATH, data[Channels.WEIGHTS]['sets'][i], 'custom_weights')       
                #os.path.join((data[Channels.WEIGHTS]['files'][i][:+]),'.custom.tif')
                cust_weight_fn = data[Channels.WEIGHTS]['files'][i] ##add custom to this fn!!!!!!!!!!!! or do i want to keep fn as before for forward compatability?
                print(cust_weight_folder, cust_weight_fn)
                make_folder(cust_weight_folder)
                io.imsave(os.path.join(cust_weight_folder, cust_weight_fn), cust_wmap.astype(np.float32))
                
                ## adding save out of the weight masks
                w_mask = viewer.layers['weightmask'].data[i,...].astype(np.bool)                
                weight_mask_folder = os.path.join(DATA_PATH, data[Channels.WEIGHTS]['sets'][i], 'weight_masks')
                weight_mask_fn = data[Channels.MASK]['files'][i] ##add weight to fn
                print(weight_mask_folder, weight_mask_fn)
                make_folder(weight_mask_folder)
                io.imsave(os.path.join(weight_mask_folder, weight_mask_fn), w_mask.astype(np.float32))
                
                
        # write out a JSON file with the data
        jfn = os.path.join(DATA_PATH, 'training_metadata.json')
        jdata = {}
        for channel in data.keys():
            jdata[channel.name.lower()] = data[channel]['path'] 
            
        with open(jfn, 'w') as json_file:
            json.dump(jdata, json_file, indent=2, separators=(',', ': '))
# Out:
# Directory  /Users/nathanday/lowe_lab/fucci/set1/results  already exists
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# ~/anaconda3/envs/napari/lib/python3.7/site-packages/vispy/app/backends/_qt.py in keyPressEvent(self, ev)
#     500
#     501     def keyPressEvent(self, ev):
# --> 502         self._keyEvent(self._vispy_canvas.events.key_press, ev)
#     503
#     504     def keyReleaseEvent(self, ev):
#
# ~/anaconda3/envs/napari/lib/python3.7/site-packages/vispy/app/backends/_qt.py in _keyEvent(self, func, ev)
#     549             key = None
#     550         mod = self._modifiers(ev)
# --> 551         func(native=ev, key=key, text=text_type(ev.text()), modifiers=mod)
#     552
#     553     def _modifiers(self, event):
#
# ~/anaconda3/envs/napari/lib/python3.7/site-packages/vispy/util/event.py in __call__(self, *args, **kwargs)
#     453                     continue
#     454
# --> 455                 self._invoke_callback(cb, event)
#     456                 if event.blocked:
#     457                     break
#
# ~/anaconda3/envs/napari/lib/python3.7/site-packages/vispy/util/event.py in _invoke_callback(self, cb, event)
#     473             _handle_exception(self.ignore_callback_errors,
#     474                               self.print_callback_errors,
# --> 475                               self, cb_event=(cb, event))
#     476
#     477     def _prepare_event(self, *args, **kwargs):
#
# ~/anaconda3/envs/napari/lib/python3.7/site-packages/vispy/util/event.py in _invoke_callback(self, cb, event)
#     469     def _invoke_callback(self, cb, event):
#     470         try:
# --> 471             cb(event)
#     472         except Exception:
#     473             _handle_exception(self.ignore_callback_errors,
#
# ~/anaconda3/envs/napari/lib/python3.7/site-packages/napari/_qt/qt_viewer.py in on_key_press(self, event)
#     529
#     530         func = parent.keymap[comb]
# --> 531         gen = func(parent)
#     532
#     533         if inspect.isgenerator(gen):
#
# <ipython-input-20-3c2ff26817ca> in k_measure(viewer)
#      55     @viewer.bind_key('m')
#      56     def k_measure(viewer):
# ---> 57         measure(viewer)
#      58
#      59     @viewer.bind_key('w')
#
# <ipython-input-16-40776c71dd8a> in measure(viewer)
#      13
#      14         stat_file_dir = os.path.join(dirName, 'image numbers' + str(INDEX_OF_IMAGES))
# ---> 15         os.mkdir(stat_file_dir)
#      16         stat_file = os.path.join(stat_file_dir, 'stats.csv')
#      17
#
# FileExistsError: [Errno 17] File exists: '/Users/nathanday/lowe_lab/fucci/set1/results/image numbersALL'
# Directory  /Users/nathanday/lowe_lab/fucci/set1/results  already exists
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# ~/anaconda3/envs/napari/lib/python3.7/site-packages/vispy/app/backends/_qt.py in keyPressEvent(self, ev)
#     500
#     501     def keyPressEvent(self, ev):
# --> 502         self._keyEvent(self._vispy_canvas.events.key_press, ev)
#     503
#     504     def keyReleaseEvent(self, ev):
#
# ~/anaconda3/envs/napari/lib/python3.7/site-packages/vispy/app/backends/_qt.py in _keyEvent(self, func, ev)
#     549             key = None
#     550         mod = self._modifiers(ev)
# --> 551         func(native=ev, key=key, text=text_type(ev.text()), modifiers=mod)
#     552
#     553     def _modifiers(self, event):
#
# ~/anaconda3/envs/napari/lib/python3.7/site-packages/vispy/util/event.py in __call__(self, *args, **kwargs)
#     453                     continue
#     454
# --> 455                 self._invoke_callback(cb, event)
#     456                 if event.blocked:
#     457                     break
#
# ~/anaconda3/envs/napari/lib/python3.7/site-packages/vispy/util/event.py in _invoke_callback(self, cb, event)
#     473             _handle_exception(self.ignore_callback_errors,
#     474                               self.print_callback_errors,
# --> 475                               self, cb_event=(cb, event))
#     476
#     477     def _prepare_event(self, *args, **kwargs):
#
# ~/anaconda3/envs/napari/lib/python3.7/site-packages/vispy/util/event.py in _invoke_callback(self, cb, event)
#     469     def _invoke_callback(self, cb, event):
#     470         try:
# --> 471             cb(event)
#     472         except Exception:
#     473             _handle_exception(self.ignore_callback_errors,
#
# ~/anaconda3/envs/napari/lib/python3.7/site-packages/napari/_qt/qt_viewer.py in on_key_press(self, event)
#     529
#     530         func = parent.keymap[comb]
# --> 531         gen = func(parent)
#     532
#     533         if inspect.isgenerator(gen):
#
# <ipython-input-20-3c2ff26817ca> in k_measure(viewer)
#      55     @viewer.bind_key('m')
#      56     def k_measure(viewer):
# ---> 57         measure(viewer)
#      58
#      59     @viewer.bind_key('w')
#
# <ipython-input-16-40776c71dd8a> in measure(viewer)
#      13
#      14         stat_file_dir = os.path.join(dirName, 'image numbers' + str(INDEX_OF_IMAGES))
# ---> 15         os.mkdir(stat_file_dir)
#      16         stat_file = os.path.join(stat_file_dir, 'stats.csv')
#      17
#
# FileExistsError: [Errno 17] File exists: '/Users/nathanday/lowe_lab/fucci/set1/results/image numbersALL'
# Directory  /Users/nathanday/lowe_lab/fucci/set1/results  already exists
#      GFP Intensity RFP Intensity Phase Intensity  Area       x       y
# 0          1626428       2675515       158340734  6617  126.20  919.11
# 1          1603424       2676191       153163572  6405  120.91  912.93
# 2          1685192       2827291       152809532  6467  116.03  908.11
# 3          1679822       2767949       148365747  6488  110.13  905.19
# 4          1725750       2819357       140716508  6701  110.19  901.96
# ...            ...           ...             ...   ...     ...     ...
# 1088        816369        962695        77659786  4295  236.57  912.03
# 1089        836339       1027816        75723442  4380  238.17  909.05
# 1090        852500       1022530        77152507  4514  236.15  910.80
# 1091        730140        902558        65545026  3747  238.90  910.28
# 1092        823866        996968        77499572  4375  237.70  910.66
#
# [1093 rows x 6 columns]
# 2468-never-too-late, I counted all them cells THANK U
# Directory  /Users/nathanday/lowe_lab/fucci/set1/results  already exists
#      GFP Intensity RFP Intensity Phase Intensity  Area       x       y
# 0          1626428       2675515       158340734  6617  126.20  919.11
# 1          1603424       2676191       153163572  6405  120.91  912.93
# 2          1685192       2827291       152809532  6467  116.03  908.11
# 3          1679822       2767949       148365747  6488  110.13  905.19
# 4          1725750       2819357       140716508  6701  110.19  901.96
# ...            ...           ...             ...   ...     ...     ...
# 1088        816369        962695        77659786  4295  236.57  912.03
# 1089        836339       1027816        75723442  4380  238.17  909.05
# 1090        852500       1022530        77152507  4514  236.15  910.80
# 1091        730140        902558        65545026  3747  238.90  910.28
# 1092        823866        996968        77499572  4375  237.70  910.66
#
# [1093 rows x 6 columns]
# 2468-never-too-late, I counted all them cells THANK U
# Directory  /Users/nathanday/lowe_lab/fucci/set1/results  already exists
#      GFP Intensity RFP Intensity Phase Intensity  Area       x       y
# 0          1626428       2675515       158340734  6617  126.20  919.11
# 1          1603424       2676191       153163572  6405  120.91  912.93
# 2          1685192       2827291       152809532  6467  116.03  908.11
# 3          1679822       2767949       148365747  6488  110.13  905.19
# 4          1725750       2819357       140716508  6701  110.19  901.96
# ...            ...           ...             ...   ...     ...     ...
# 1088        816369        962695        77659786  4295  236.57  912.03
# 1089        836339       1027816        75723442  4380  238.17  909.05
# 1090        852500       1022530        77152507  4514  236.15  910.80
# 1091        730140        902558        65545026  3747  238.90  910.28
# 1092        823866        996968        77499572  4375  237.70  910.66
#
# [1093 rows x 6 columns]
# 2468-never-too-late, I counted all them cells THANK U
# Directory  /Users/nathanday/lowe_lab/fucci/set1/results  already exists
#      GFP Intensity RFP Intensity Phase Intensity  Area       x       y
# 0          1626428       2675515       158340734  6617  126.20  919.11
# 1          1603424       2676191       153163572  6405  120.91  912.93
# 2          1685192       2827291       152809532  6467  116.03  908.11
# 3          1679822       2767949       148365747  6488  110.13  905.19
# 4          1725750       2819357       140716508  6701  110.19  901.96
# ...            ...           ...             ...   ...     ...     ...
# 1088        816369        962695        77659786  4295  236.57  912.03
# 1089        836339       1027816        75723442  4380  238.17  909.05
# 1090        852500       1022530        77152507  4514  236.15  910.80
# 1091        730140        902558        65545026  3747  238.90  910.28
# 1092        823866        996968        77499572  4375  237.70  910.66
#
# [1093 rows x 6 columns]
# 2468-never-too-late, I counted all them cells THANK U
# Directory  /Users/nathanday/lowe_lab/fucci/set1/results  already exists
#      GFP Intensity RFP Intensity Phase Intensity  Area       x       y
# 0          1626428       2675515       158340734  6617  126.20  919.11
# 1          1603424       2676191       153163572  6405  120.91  912.93
# 2          1685192       2827291       152809532  6467  116.03  908.11
# 3          1679822       2767949       148365747  6488  110.13  905.19
# 4          1725750       2819357       140716508  6701  110.19  901.96
# ...            ...           ...             ...   ...     ...     ...
# 1088        816369        962695        77659786  4295  236.57  912.03
# 1089        836339       1027816        75723442  4380  238.17  909.05
# 1090        852500       1022530        77152507  4514  236.15  910.80
# 1091        730140        902558        65545026  3747  238.90  910.28
# 1092        823866        996968        77499572  4375  237.70  910.66
#
# [1093 rows x 6 columns]
# 2468-never-too-late, I counted all them cells THANK U
# Directory  /Users/nathanday/lowe_lab/fucci/set1/results  already exists
#      GFP Intensity RFP Intensity Phase Intensity  Area       x       y
# 0          1626428       2675515       158340734  6617  126.20  919.11
# 1          1603424       2676191       153163572  6405  120.91  912.93
# 2          1685192       2827291       152809532  6467  116.03  908.11
# 3          1679822       2767949       148365747  6488  110.13  905.19
# 4          1725750       2819357       140716508  6701  110.19  901.96
# ...            ...           ...             ...   ...     ...     ...
# 1088        816369        962695        77659786  4295  236.57  912.03
# 1089        836339       1027816        75723442  4380  238.17  909.05
# 1090        852500       1022530        77152507  4514  236.15  910.80
# 1091        730140        902558        65545026  3747  238.90  910.28
# 1092        823866        996968        77499572  4375  237.70  910.66
#
# [1093 rows x 6 columns]
# 2468-never-too-late, I counted all them cells THANK U
# Directory  /Users/nathanday/lowe_lab/fucci/set1/results  already exists
#      GFP Intensity RFP Intensity Phase Intensity  Area       x       y
# 0          1626428       2675515       158340734  6617  126.20  919.11
# 1          1603424       2676191       153163572  6405  120.91  912.93
# 2          1685192       2827291       152809532  6467  116.03  908.11
# 3          1679822       2767949       148365747  6488  110.13  905.19
# 4          1725750       2819357       140716508  6701  110.19  901.96
# ...            ...           ...             ...   ...     ...     ...
# 1088        816369        962695        77659786  4295  236.57  912.03
# 1089        836339       1027816        75723442  4380  238.17  909.05
# 1090        852500       1022530        77152507  4514  236.15  910.80
# 1091        730140        902558        65545026  3747  238.90  910.28
# 1092        823866        996968        77499572  4375  237.70  910.66
#
# [1093 rows x 6 columns]
# 2468-never-too-late, I counted all them cells THANK U
# Directory  /Users/nathanday/lowe_lab/fucci/set1/results  already exists
#      GFP Intensity RFP Intensity Phase Intensity  Area       x       y
# 0          1626428       2675515       158340734  6617  126.20  919.11
# 1          1603424       2676191       153163572  6405  120.91  912.93
# 2          1685192       2827291       152809532  6467  116.03  908.11
# 3          1679822       2767949       148365747  6488  110.13  905.19
# 4          1725750       2819357       140716508  6701  110.19  901.96
# ...            ...           ...             ...   ...     ...     ...
# 1088        816369        962695        77659786  4295  236.57  912.03
# 1089        836339       1027816        75723442  4380  238.17  909.05
# 1090        852500       1022530        77152507  4514  236.15  910.80
# 1091        730140        902558        65545026  3747  238.90  910.28
# 1092        823866        996968        77499572  4375  237.70  910.66
#
# [1093 rows x 6 columns]
# 2468-never-too-late, I counted all them cells THANK U

# %%
# # convert segmentation output labels to multichannel stacks

# p = '/Users/arl/Dropbox/Data/TrainingData/set12'
# files = [f for f in os.listdir(os.path.join(p,'labels')) if f.endswith('.tif')]
# for f in files:
#     mask = io.imread(os.path.join(p, 'labels', f))
#     print(mask.shape)
#     gfp = mask==1
#     rfp = mask==2
#     new_mask = np.stack([gfp, rfp], axis=0)
#     io.imsave(os.path.join(p,f), new_mask.astype('uint8'))
