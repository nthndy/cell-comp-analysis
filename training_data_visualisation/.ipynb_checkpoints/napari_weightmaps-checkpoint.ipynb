# %% [markdown]
# # NAPARI visualization of UNet Training Data
#
# You can use this notebook to view, modified and save out training data for UNet models
#
# Labels:
# + 0 - background
# + 1 - GFP/Phase
# + 2 - RFP
#
#
# Extra key bindings:
# + 'w' - calculate weightmap
# + 'q' - calculate custom annotated weightmap (weightmask * weightmap)
# + '/' - save label current displayed
# + 's' - save all labels
# + 'o' - output all weightmaps and metadata for tfrecord creation
# + '\>' - grow the label under the mouse cursor
# + '\<' - shrink the label under the mouse cursor
# + 'h' - fill holes in cell mask under the mouse cursor
# + '0' - clear all cell labels that aren't currently under the cursor
# + 'n' - count cells (will be updated to collect more stats)
# + 'g' - output gaussian noise images for missing fluorescence images
# + 'm' - output results of "measurements" function, note- think you need to be on the GFP layer for this to work?

# %% [markdown]
# ---
#
# ```
# Authors:
# - Alan R. Lowe (a.lowe@ucl.ac.uk)
# - Nathan J. Day (nathan.day.16@ucl.ac.uk)
# ```

# %% [markdown]
# ---
# ## Set up the data path, channel(s) used, weight amplitude and the number of images to load

# %%
#DATA_PATH = os.path.normpath('C:/Users/Nathan/data/training/training_data')
DATA_PATH = '/home/nathan/data/fucci/fucci1_171201/sandbox/'

WEIGHT_AMPLITUDE = 0.
ACQUISITION_CHANNELS = ['GFP'] #, 'GFP' , 'RFP'] #complete sets
INCOMPLETE_CHANNELS = [] # 'IRFP'] #list here if sets incomplete ie some images missing and need to supplement w gaus noise
#NUMBER_OF_IMAGES_TO_LOAD = 10 #in each set, from index 0, loads in numerical order, if all images desired then enter 'ALL'
INDEX_OF_IMAGES =  [0,500] #enter [min, max] or 'ALL'
#INDEX_OF_IMAGES = [minimum:maximum]
#ACQUISITION_CHANNELS = ['GFP', 'RFP']

# %% [markdown]
# ---

# %%
import os
import re
import enum
import json
import csv
import napari
import pandas as pd
from skimage import io
from skimage.util import random_noise
import numpy as np
from scipy import ndimage
from itertools import islice

from scipy.ndimage.morphology import distance_transform_edt
from scipy.ndimage import gaussian_filter

import matplotlib.pyplot as plt

# %%
@enum.unique
class Channels(enum.Enum):
    BRIGHTFIELD = 0 
    GFP = 1
    RFP = 2
    IRFP = 3
    PHASE = 4
    WEIGHTS = 98
    MASK = 99

# %%
global filename

def strip_modified_filename(filename):
    if filename.endswith('.modified.tif'):
        stripped_fn = filename[:-len('.modified.tif')]
        return stripped_fn
    return filename

def make_folder(foldername):
    if os.path.exists(foldername):
        return
    os.mkdir(foldername)
    
def file_root(filename):  #searches for the filename pattern inside the given filename, returns the result of that search as grps
    FILENAME_PATTERN = r'([a-zA-Z0-9]+)_([a-zA-Z0-9]+)_*.tif'
    grps = re.search(FILENAME_PATTERN, filename)
    return grps

def load_training_data(pth, channels=[Channels.GFP, Channels.RFP]):
    """ load training data for visualisation with napari"""
          
    # find the sets and sort them
    global sets #allows sets to be called from another function
    sets = [f for f in os.listdir(pth) if os.path.isdir(os.path.join(pth, f))]
    sets.sort(key = lambda s: int(s[3:]))
    
    def set_filename_format(filename): #both functions below serve to find filenames regardless of x_gfp.tif or gfp_x.tif
        grps = file_root(filename)
        
        if grps.group(1) in [c.name.lower() for c in all_channels]: #if a feature about the fn pattern is in the channel name (ie gfp) then FNFMT = 2, allowing for x_gfp.tif or gfp_x.tif to be sorted 
            FILENAME_FORMAT = 2 #gfp_x.tif
        else:
            FILENAME_FORMAT = 1 #x_gfp.tif
                        
        def filename_formatter(filename, channel):
            # assert(channel in [c.name.lower() for c in all_channels])
            grps = file_root(filename)

            return f'{grps.group(FILENAME_FORMAT)}_{channel}.tif'
            # return '{}_{}.tif'.format(*[channel, grps.group(FILENAME_FORMAT)])
        
        return filename_formatter
        
    all_channels = [Channels.MASK, Channels.WEIGHTS]+channels
    global files
    files = {k:{'files':[], 'data':[], 'sets':[], 'path':[]} for k in all_channels}
    all_channels.remove(Channels.WEIGHTS)
       
    for s in sets:

        # root_folders
        l_root = os.path.join(pth, s, 'labels')
        
        # check that this folder exists 
        if not os.path.exists(l_root):
            raise IOError(f'{l_root} does not exist. Do you need to rename label -> labels?')

        # get the training label files
        label_files = [f for f in os.listdir(l_root) if f.endswith('.tif')]
                
        # sort to remove unmodified files and replace with the modified files
        unmodified_files, modified_files = [], []
        
        #for index, item in enumerate(islice(items, limit)):
        for i, f in enumerate(label_files): #introducing islice here allows you to choose size of dataset! but only in a random order
            if f.endswith('.modified.tif'):
                modified_files.append(strip_modified_filename(f))
            else:
                unmodified_files.append(f)
                
        unmodified_files = list(set(unmodified_files).difference(set(modified_files))) #this is only unmod where mod doesnt exist
        label_files_full = unmodified_files + [f+'.modified.tif' for f in modified_files]    
        label_files_full.sort(key = lambda f: int(f[0:4])) #sorts files numerically

        #N = NUMBER_OF_IMAGES_TO_LOAD
        #n = INDEX_OF_IMAGES[0]
        #m = INDEX_OF_IMAGES[1]
        
        if INDEX_OF_IMAGES == 'ALL':
            label_files = label_files_full
        else:
            n = INDEX_OF_IMAGES[0]
            m = INDEX_OF_IMAGES[1]
            label_files = label_files_full[n:m] #cuts list of files to n->m images       
            #label_files = label_files_full[INDEX_OF_IMAGES]

        """
        if N == 'ALL':
            label_files = label_files_full
        elif N > 0:
            label_files = label_files_full[:N] #cuts list of files to N images
        else:
            label_files = label_files_full[n:m] #cuts list of files to n->m images       
        ## MAKE THIS ELIF TIDIER SO ONLY ONE INPUT IS REQUIRED ##        
        """
        global fnfmt
        fnfmt = set_filename_format(label_files[0]) #why only label_files[0]? -> bc only need one example to set the fnfmt
                        
        files[Channels.MASK]['path'] += [s+'/labels/'+f for f in label_files]
        files[Channels.MASK]['files'] += [strip_modified_filename(f) for f in label_files]
        files[Channels.MASK]['data'] += [io.imread(os.path.join(l_root, f)) for f in label_files]
        files[Channels.MASK]['sets'] += [s] * len(label_files)
        
        for channel in channels:
            
           #if cfiles channel.name.lower dir doesnt contain gfp or rfp then add option to create noise data,
            channel_dir = os.path.join(pth, s, channel.name.lower())            
            #if os.path.exists(channel_dir): #if fluor/phase channels exist, continue as norm
            cfiles = [fnfmt(l, channel.name.lower()) for l in label_files]
            files[channel]['path'] += [s+'/'+channel.name.lower()+'/'+f for f in cfiles]
            files[channel]['files'] += cfiles #filenames
            files[channel]['data'] += [io.imread(os.path.join(pth, s, channel.name.lower(), f)) for f in cfiles] #actualdata
            files[channel]['sets'] += [s] * len(label_files)
            
        # now look for weights 
        w_root = os.path.join(pth, s, 'weights') ### change this back to 'weights' and have func to rename previous weight folder?
        #if os.path.exists(w_root):
        wfiles = [fnfmt(l, 'weights') for l in label_files]
        for weight_file in wfiles:
            files[Channels.WEIGHTS]['path'] += [f'{s}/weights/{weight_file}']
            files[Channels.WEIGHTS]['files'] += [weight_file]
            files[Channels.WEIGHTS]['sets'] += [s]
            if os.path.exists(os.path.join(w_root, weight_file)):
                files[Channels.WEIGHTS]['data'] += [io.imread(os.path.join(w_root, weight_file)).astype(np.float32)]
            else:
                print(f'Adding empty weight file: {weight_file}')
                mask_shape = files[channels[0]]['data'][0].shape
                files[Channels.WEIGHTS]['data'] += [np.zeros(mask_shape, dtype=np.float32)]
                        

    w_root = os.path.join(pth, s, 'weights')
                                                         
    # now make image stacks 
    for channel in files.keys():
        for i, im in enumerate(files[channel]['data']):
            print(channel, files[channel]['path'][i], im.shape, im.dtype)
        
        files[channel]['data'] = np.stack(files[channel]['data'], axis=0)
        
    global shape
    shape = files[channels[0]]['data'][0].shape
    
    return files

# %%
channels = [Channels[c.upper()] for c in ACQUISITION_CHANNELS]
data = load_training_data(DATA_PATH, channels)
# Out:
# /home/nathan/analysis/training_data_visualisation/tifffile.py:2170: UserWarning: failed to import _tifffile.decodepackbits
#   warnings.warn("failed to import %s" % module_function)
# /home/nathan/analysis/training_data_visualisation/tifffile.py:2170: UserWarning: failed to import _tifffile.decodelzw
#   warnings.warn("failed to import %s" % module_function)
# /home/nathan/analysis/training_data_visualisation/tifffile.py:2170: UserWarning: failed to import _tifffile.unpackints
#   warnings.warn("failed to import %s" % module_function)
# Adding empty weight file: 0000_weights.tif
# Adding empty weight file: 0001_weights.tif
# Adding empty weight file: 0002_weights.tif
# Adding empty weight file: 0003_weights.tif
# Adding empty weight file: 0004_weights.tif
# Adding empty weight file: 0005_weights.tif
# Adding empty weight file: 0006_weights.tif
# Adding empty weight file: 0007_weights.tif
# Adding empty weight file: 0008_weights.tif
# Adding empty weight file: 0009_weights.tif
# Adding empty weight file: 0010_weights.tif
# Adding empty weight file: 0011_weights.tif
# Adding empty weight file: 0012_weights.tif
# Adding empty weight file: 0013_weights.tif
# Adding empty weight file: 0014_weights.tif
# Adding empty weight file: 0015_weights.tif
# Adding empty weight file: 0016_weights.tif
# Adding empty weight file: 0017_weights.tif
# Adding empty weight file: 0018_weights.tif
# Adding empty weight file: 0019_weights.tif
# Adding empty weight file: 0020_weights.tif
# Adding empty weight file: 0021_weights.tif
# Adding empty weight file: 0022_weights.tif
# Adding empty weight file: 0023_weights.tif
# Adding empty weight file: 0024_weights.tif
# Adding empty weight file: 0025_weights.tif
# Adding empty weight file: 0026_weights.tif
# Adding empty weight file: 0027_weights.tif
# Adding empty weight file: 0028_weights.tif
# Adding empty weight file: 0029_weights.tif
# Adding empty weight file: 0030_weights.tif
# Adding empty weight file: 0031_weights.tif
# Adding empty weight file: 0032_weights.tif
# Adding empty weight file: 0033_weights.tif
# Adding empty weight file: 0034_weights.tif
# Adding empty weight file: 0035_weights.tif
# Adding empty weight file: 0036_weights.tif
# Adding empty weight file: 0037_weights.tif
# Adding empty weight file: 0038_weights.tif
# Adding empty weight file: 0039_weights.tif
# Adding empty weight file: 0040_weights.tif
# Adding empty weight file: 0041_weights.tif
# Adding empty weight file: 0042_weights.tif
# Adding empty weight file: 0043_weights.tif
# Adding empty weight file: 0044_weights.tif
# Adding empty weight file: 0045_weights.tif
# Adding empty weight file: 0046_weights.tif
# Adding empty weight file: 0047_weights.tif
# Adding empty weight file: 0048_weights.tif
# Adding empty weight file: 0049_weights.tif
# Adding empty weight file: 0050_weights.tif
# Adding empty weight file: 0051_weights.tif
# Adding empty weight file: 0052_weights.tif
# Adding empty weight file: 0053_weights.tif
# Adding empty weight file: 0054_weights.tif
# Adding empty weight file: 0055_weights.tif
# Adding empty weight file: 0056_weights.tif
# Adding empty weight file: 0057_weights.tif
# Adding empty weight file: 0058_weights.tif
# Adding empty weight file: 0059_weights.tif
# Adding empty weight file: 0060_weights.tif
# Adding empty weight file: 0061_weights.tif
# Adding empty weight file: 0062_weights.tif
# Adding empty weight file: 0063_weights.tif
# Adding empty weight file: 0064_weights.tif
# Adding empty weight file: 0065_weights.tif
# Adding empty weight file: 0066_weights.tif
# Adding empty weight file: 0067_weights.tif
# Adding empty weight file: 0068_weights.tif
# Adding empty weight file: 0069_weights.tif
# Adding empty weight file: 0070_weights.tif
# Adding empty weight file: 0071_weights.tif
# Adding empty weight file: 0072_weights.tif
# Adding empty weight file: 0073_weights.tif
# Adding empty weight file: 0074_weights.tif
# Adding empty weight file: 0075_weights.tif
# Adding empty weight file: 0076_weights.tif
# Adding empty weight file: 0077_weights.tif
# Adding empty weight file: 0078_weights.tif
# Adding empty weight file: 0079_weights.tif
# Adding empty weight file: 0080_weights.tif
# Adding empty weight file: 0081_weights.tif
# Adding empty weight file: 0082_weights.tif
# Adding empty weight file: 0083_weights.tif
# Adding empty weight file: 0084_weights.tif
# Adding empty weight file: 0085_weights.tif
# Adding empty weight file: 0086_weights.tif
# Adding empty weight file: 0087_weights.tif
# Adding empty weight file: 0088_weights.tif
# Adding empty weight file: 0089_weights.tif
# Adding empty weight file: 0090_weights.tif
# Adding empty weight file: 0091_weights.tif
# Adding empty weight file: 0092_weights.tif
# Adding empty weight file: 0093_weights.tif
# Adding empty weight file: 0094_weights.tif
# Adding empty weight file: 0095_weights.tif
# Adding empty weight file: 0096_weights.tif
# Adding empty weight file: 0097_weights.tif
# Adding empty weight file: 0098_weights.tif
# Adding empty weight file: 0099_weights.tif
# Adding empty weight file: 0100_weights.tif
# Adding empty weight file: 0101_weights.tif
# Adding empty weight file: 0102_weights.tif
# Adding empty weight file: 0103_weights.tif
# Adding empty weight file: 0104_weights.tif
# Adding empty weight file: 0105_weights.tif
# Adding empty weight file: 0106_weights.tif
# Adding empty weight file: 0107_weights.tif
# Adding empty weight file: 0108_weights.tif
# Adding empty weight file: 0109_weights.tif
# Adding empty weight file: 0110_weights.tif
# Adding empty weight file: 0111_weights.tif
# Adding empty weight file: 0112_weights.tif
# Adding empty weight file: 0113_weights.tif
# Adding empty weight file: 0114_weights.tif
# Adding empty weight file: 0115_weights.tif
# Adding empty weight file: 0116_weights.tif
# Adding empty weight file: 0117_weights.tif
# Adding empty weight file: 0118_weights.tif
# Adding empty weight file: 0119_weights.tif
# Adding empty weight file: 0120_weights.tif
# Adding empty weight file: 0121_weights.tif
# Adding empty weight file: 0122_weights.tif
# Adding empty weight file: 0123_weights.tif
# Adding empty weight file: 0124_weights.tif
# Adding empty weight file: 0125_weights.tif
# Adding empty weight file: 0126_weights.tif
# Adding empty weight file: 0127_weights.tif
# Adding empty weight file: 0128_weights.tif
# Adding empty weight file: 0129_weights.tif
# Adding empty weight file: 0130_weights.tif
# Adding empty weight file: 0131_weights.tif
# Adding empty weight file: 0132_weights.tif
# Adding empty weight file: 0133_weights.tif
# Adding empty weight file: 0134_weights.tif
# Adding empty weight file: 0135_weights.tif
# Adding empty weight file: 0136_weights.tif
# Adding empty weight file: 0137_weights.tif
# Adding empty weight file: 0138_weights.tif
# Adding empty weight file: 0139_weights.tif
# Adding empty weight file: 0140_weights.tif
# Adding empty weight file: 0141_weights.tif
# Adding empty weight file: 0142_weights.tif
# Adding empty weight file: 0143_weights.tif
# Adding empty weight file: 0144_weights.tif
# Adding empty weight file: 0145_weights.tif
# Adding empty weight file: 0146_weights.tif
# Adding empty weight file: 0147_weights.tif
# Adding empty weight file: 0148_weights.tif
# Adding empty weight file: 0149_weights.tif
# Adding empty weight file: 0150_weights.tif
# Adding empty weight file: 0151_weights.tif
# Adding empty weight file: 0152_weights.tif
# Adding empty weight file: 0153_weights.tif
# Adding empty weight file: 0154_weights.tif
# Adding empty weight file: 0155_weights.tif
# Adding empty weight file: 0156_weights.tif
# Adding empty weight file: 0157_weights.tif
# Adding empty weight file: 0158_weights.tif
# Adding empty weight file: 0159_weights.tif
# Adding empty weight file: 0160_weights.tif
# Adding empty weight file: 0161_weights.tif
# Adding empty weight file: 0162_weights.tif
# Adding empty weight file: 0163_weights.tif
# Adding empty weight file: 0164_weights.tif
# Adding empty weight file: 0165_weights.tif
# Adding empty weight file: 0166_weights.tif
# Adding empty weight file: 0167_weights.tif
# Adding empty weight file: 0168_weights.tif
# Adding empty weight file: 0169_weights.tif
# Adding empty weight file: 0170_weights.tif
# Adding empty weight file: 0171_weights.tif
# Adding empty weight file: 0172_weights.tif
# Adding empty weight file: 0173_weights.tif
# Adding empty weight file: 0174_weights.tif
# Adding empty weight file: 0175_weights.tif
# Adding empty weight file: 0176_weights.tif
# Adding empty weight file: 0177_weights.tif
# Adding empty weight file: 0178_weights.tif
# Adding empty weight file: 0179_weights.tif
# Adding empty weight file: 0180_weights.tif
# Adding empty weight file: 0181_weights.tif
# Adding empty weight file: 0182_weights.tif
# Adding empty weight file: 0183_weights.tif
# Adding empty weight file: 0184_weights.tif
# Adding empty weight file: 0185_weights.tif
# Adding empty weight file: 0186_weights.tif
# Adding empty weight file: 0187_weights.tif
# Adding empty weight file: 0188_weights.tif
# Adding empty weight file: 0189_weights.tif
# Adding empty weight file: 0190_weights.tif
# Adding empty weight file: 0191_weights.tif
# Adding empty weight file: 0192_weights.tif
# Adding empty weight file: 0193_weights.tif
# Adding empty weight file: 0194_weights.tif
# Adding empty weight file: 0195_weights.tif
# Adding empty weight file: 0196_weights.tif
# Adding empty weight file: 0197_weights.tif
# Adding empty weight file: 0198_weights.tif
# Adding empty weight file: 0199_weights.tif
# Adding empty weight file: 0200_weights.tif
# Adding empty weight file: 0201_weights.tif
# Adding empty weight file: 0202_weights.tif
# Adding empty weight file: 0203_weights.tif
# Adding empty weight file: 0204_weights.tif
# Adding empty weight file: 0205_weights.tif
# Adding empty weight file: 0206_weights.tif
# Adding empty weight file: 0207_weights.tif
# Adding empty weight file: 0208_weights.tif
# Adding empty weight file: 0209_weights.tif
# Adding empty weight file: 0210_weights.tif
# Adding empty weight file: 0211_weights.tif
# Adding empty weight file: 0212_weights.tif
# Adding empty weight file: 0213_weights.tif
# Adding empty weight file: 0214_weights.tif
# Adding empty weight file: 0215_weights.tif
# Adding empty weight file: 0216_weights.tif
# Adding empty weight file: 0217_weights.tif
# Adding empty weight file: 0218_weights.tif
# Adding empty weight file: 0219_weights.tif
# Adding empty weight file: 0220_weights.tif
# Adding empty weight file: 0221_weights.tif
# Adding empty weight file: 0222_weights.tif
# Adding empty weight file: 0223_weights.tif
# Adding empty weight file: 0224_weights.tif
# Adding empty weight file: 0225_weights.tif
# Adding empty weight file: 0226_weights.tif
# Adding empty weight file: 0227_weights.tif
# Adding empty weight file: 0228_weights.tif
# Adding empty weight file: 0229_weights.tif
# Adding empty weight file: 0230_weights.tif
# Adding empty weight file: 0231_weights.tif
# Adding empty weight file: 0232_weights.tif
# Adding empty weight file: 0233_weights.tif
# Adding empty weight file: 0234_weights.tif
# Adding empty weight file: 0235_weights.tif
# Adding empty weight file: 0236_weights.tif
# Adding empty weight file: 0237_weights.tif
# Adding empty weight file: 0238_weights.tif
# Adding empty weight file: 0239_weights.tif
# Adding empty weight file: 0240_weights.tif
# Adding empty weight file: 0241_weights.tif
# Adding empty weight file: 0242_weights.tif
# Adding empty weight file: 0243_weights.tif
# Adding empty weight file: 0244_weights.tif
# Adding empty weight file: 0245_weights.tif
# Adding empty weight file: 0246_weights.tif
# Adding empty weight file: 0247_weights.tif
# Adding empty weight file: 0248_weights.tif
# Adding empty weight file: 0249_weights.tif
# Adding empty weight file: 0250_weights.tif
# Adding empty weight file: 0251_weights.tif
# Adding empty weight file: 0252_weights.tif
# Adding empty weight file: 0253_weights.tif
# Adding empty weight file: 0254_weights.tif
# Adding empty weight file: 0255_weights.tif
# Adding empty weight file: 0256_weights.tif
# Adding empty weight file: 0257_weights.tif
# Adding empty weight file: 0258_weights.tif
# Adding empty weight file: 0259_weights.tif
# Adding empty weight file: 0260_weights.tif
# Adding empty weight file: 0261_weights.tif
# Adding empty weight file: 0262_weights.tif
# Adding empty weight file: 0263_weights.tif
# Adding empty weight file: 0264_weights.tif
# Adding empty weight file: 0265_weights.tif
# Adding empty weight file: 0266_weights.tif
# Adding empty weight file: 0267_weights.tif
# Adding empty weight file: 0268_weights.tif
# Adding empty weight file: 0269_weights.tif
# Adding empty weight file: 0270_weights.tif
# Adding empty weight file: 0271_weights.tif
# Adding empty weight file: 0272_weights.tif
# Adding empty weight file: 0273_weights.tif
# Adding empty weight file: 0274_weights.tif
# Adding empty weight file: 0275_weights.tif
# Adding empty weight file: 0276_weights.tif
# Adding empty weight file: 0277_weights.tif
# Adding empty weight file: 0278_weights.tif
# Adding empty weight file: 0279_weights.tif
# Adding empty weight file: 0280_weights.tif
# Adding empty weight file: 0281_weights.tif
# Adding empty weight file: 0282_weights.tif
# Adding empty weight file: 0283_weights.tif
# Adding empty weight file: 0284_weights.tif
# Adding empty weight file: 0285_weights.tif
# Adding empty weight file: 0286_weights.tif
# Adding empty weight file: 0287_weights.tif
# Adding empty weight file: 0288_weights.tif
# Adding empty weight file: 0289_weights.tif
# Adding empty weight file: 0290_weights.tif
# Adding empty weight file: 0291_weights.tif
# Adding empty weight file: 0292_weights.tif
# Adding empty weight file: 0293_weights.tif
# Adding empty weight file: 0294_weights.tif
# Adding empty weight file: 0295_weights.tif
# Adding empty weight file: 0296_weights.tif
# Adding empty weight file: 0297_weights.tif
# Adding empty weight file: 0298_weights.tif
# Adding empty weight file: 0299_weights.tif
# Adding empty weight file: 0300_weights.tif
# Adding empty weight file: 0301_weights.tif
# Adding empty weight file: 0302_weights.tif
# Adding empty weight file: 0303_weights.tif
# Adding empty weight file: 0304_weights.tif
# Adding empty weight file: 0305_weights.tif
# Adding empty weight file: 0306_weights.tif
# Adding empty weight file: 0307_weights.tif
# Adding empty weight file: 0308_weights.tif
# Adding empty weight file: 0309_weights.tif
# Adding empty weight file: 0310_weights.tif
# Adding empty weight file: 0311_weights.tif
# Adding empty weight file: 0312_weights.tif
# Adding empty weight file: 0313_weights.tif
# Adding empty weight file: 0314_weights.tif
# Adding empty weight file: 0315_weights.tif
# Adding empty weight file: 0316_weights.tif
# Adding empty weight file: 0317_weights.tif
# Adding empty weight file: 0318_weights.tif
# Adding empty weight file: 0319_weights.tif
# Adding empty weight file: 0320_weights.tif
# Adding empty weight file: 0321_weights.tif
# Adding empty weight file: 0322_weights.tif
# Adding empty weight file: 0323_weights.tif
# Adding empty weight file: 0324_weights.tif
# Adding empty weight file: 0325_weights.tif
# Adding empty weight file: 0326_weights.tif
# Adding empty weight file: 0327_weights.tif
# Adding empty weight file: 0328_weights.tif
# Adding empty weight file: 0329_weights.tif
# Adding empty weight file: 0330_weights.tif
# Adding empty weight file: 0331_weights.tif
# Adding empty weight file: 0332_weights.tif
# Adding empty weight file: 0333_weights.tif
# Adding empty weight file: 0334_weights.tif
# Adding empty weight file: 0335_weights.tif
# Adding empty weight file: 0336_weights.tif
# Adding empty weight file: 0337_weights.tif
# Adding empty weight file: 0338_weights.tif
# Adding empty weight file: 0339_weights.tif
# Adding empty weight file: 0340_weights.tif
# Adding empty weight file: 0341_weights.tif
# Adding empty weight file: 0342_weights.tif
# Adding empty weight file: 0343_weights.tif
# Adding empty weight file: 0344_weights.tif
# Adding empty weight file: 0345_weights.tif
# Adding empty weight file: 0346_weights.tif
# Adding empty weight file: 0347_weights.tif
# Adding empty weight file: 0348_weights.tif
# Adding empty weight file: 0349_weights.tif
# Adding empty weight file: 0350_weights.tif
# Adding empty weight file: 0351_weights.tif
# Adding empty weight file: 0352_weights.tif
# Adding empty weight file: 0353_weights.tif
# Adding empty weight file: 0354_weights.tif
# Adding empty weight file: 0355_weights.tif
# Adding empty weight file: 0356_weights.tif
# Adding empty weight file: 0357_weights.tif
# Adding empty weight file: 0358_weights.tif
# Adding empty weight file: 0359_weights.tif
# Adding empty weight file: 0360_weights.tif
# Adding empty weight file: 0361_weights.tif
# Adding empty weight file: 0362_weights.tif
# Adding empty weight file: 0363_weights.tif
# Adding empty weight file: 0364_weights.tif
# Adding empty weight file: 0365_weights.tif
# Adding empty weight file: 0366_weights.tif
# Adding empty weight file: 0367_weights.tif
# Adding empty weight file: 0368_weights.tif
# Adding empty weight file: 0369_weights.tif
# Adding empty weight file: 0370_weights.tif
# Adding empty weight file: 0371_weights.tif
# Adding empty weight file: 0372_weights.tif
# Adding empty weight file: 0373_weights.tif
# Adding empty weight file: 0374_weights.tif
# Adding empty weight file: 0375_weights.tif
# Adding empty weight file: 0376_weights.tif
# Adding empty weight file: 0377_weights.tif
# Adding empty weight file: 0378_weights.tif
# Adding empty weight file: 0379_weights.tif
# Adding empty weight file: 0380_weights.tif
# Adding empty weight file: 0381_weights.tif
# Adding empty weight file: 0382_weights.tif
# Adding empty weight file: 0383_weights.tif
# Adding empty weight file: 0384_weights.tif
# Adding empty weight file: 0385_weights.tif
# Adding empty weight file: 0386_weights.tif
# Adding empty weight file: 0387_weights.tif
# Adding empty weight file: 0388_weights.tif
# Adding empty weight file: 0389_weights.tif
# Adding empty weight file: 0390_weights.tif
# Adding empty weight file: 0391_weights.tif
# Adding empty weight file: 0392_weights.tif
# Adding empty weight file: 0393_weights.tif
# Adding empty weight file: 0394_weights.tif
# Adding empty weight file: 0395_weights.tif
# Adding empty weight file: 0396_weights.tif
# Adding empty weight file: 0397_weights.tif
# Adding empty weight file: 0398_weights.tif
# Adding empty weight file: 0399_weights.tif
# Adding empty weight file: 0400_weights.tif
# Adding empty weight file: 0401_weights.tif
# Adding empty weight file: 0402_weights.tif
# Adding empty weight file: 0403_weights.tif
# Adding empty weight file: 0404_weights.tif
# Adding empty weight file: 0405_weights.tif
# Adding empty weight file: 0406_weights.tif
# Adding empty weight file: 0407_weights.tif
# Adding empty weight file: 0408_weights.tif
# Adding empty weight file: 0409_weights.tif
# Adding empty weight file: 0410_weights.tif
# Adding empty weight file: 0411_weights.tif
# Adding empty weight file: 0412_weights.tif
# Adding empty weight file: 0413_weights.tif
# Adding empty weight file: 0414_weights.tif
# Adding empty weight file: 0415_weights.tif
# Adding empty weight file: 0416_weights.tif
# Adding empty weight file: 0417_weights.tif
# Adding empty weight file: 0418_weights.tif
# Adding empty weight file: 0419_weights.tif
# Adding empty weight file: 0420_weights.tif
# Adding empty weight file: 0421_weights.tif
# Adding empty weight file: 0422_weights.tif
# Adding empty weight file: 0423_weights.tif
# Adding empty weight file: 0424_weights.tif
# Adding empty weight file: 0425_weights.tif
# Adding empty weight file: 0426_weights.tif
# Adding empty weight file: 0427_weights.tif
# Adding empty weight file: 0428_weights.tif
# Adding empty weight file: 0429_weights.tif
# Adding empty weight file: 0430_weights.tif
# Adding empty weight file: 0431_weights.tif
# Adding empty weight file: 0432_weights.tif
# Adding empty weight file: 0433_weights.tif
# Adding empty weight file: 0434_weights.tif
# Adding empty weight file: 0435_weights.tif
# Adding empty weight file: 0436_weights.tif
# Adding empty weight file: 0437_weights.tif
# Adding empty weight file: 0438_weights.tif
# Adding empty weight file: 0439_weights.tif
# Adding empty weight file: 0440_weights.tif
# Adding empty weight file: 0441_weights.tif
# Adding empty weight file: 0442_weights.tif
# Adding empty weight file: 0443_weights.tif
# Adding empty weight file: 0444_weights.tif
# Adding empty weight file: 0445_weights.tif
# Adding empty weight file: 0446_weights.tif
# Adding empty weight file: 0447_weights.tif
# Adding empty weight file: 0448_weights.tif
# Adding empty weight file: 0449_weights.tif
# Adding empty weight file: 0450_weights.tif
# Adding empty weight file: 0451_weights.tif
# Adding empty weight file: 0452_weights.tif
# Adding empty weight file: 0453_weights.tif
# Adding empty weight file: 0454_weights.tif
# Adding empty weight file: 0455_weights.tif
# Adding empty weight file: 0456_weights.tif
# Adding empty weight file: 0457_weights.tif
# Adding empty weight file: 0458_weights.tif
# Adding empty weight file: 0459_weights.tif
# Adding empty weight file: 0460_weights.tif
# Adding empty weight file: 0461_weights.tif
# Adding empty weight file: 0462_weights.tif
# Adding empty weight file: 0463_weights.tif
# Adding empty weight file: 0464_weights.tif
# Adding empty weight file: 0465_weights.tif
# Adding empty weight file: 0466_weights.tif
# Adding empty weight file: 0467_weights.tif
# Adding empty weight file: 0468_weights.tif
# Adding empty weight file: 0469_weights.tif
# Adding empty weight file: 0470_weights.tif
# Adding empty weight file: 0471_weights.tif
# Adding empty weight file: 0472_weights.tif
# Adding empty weight file: 0473_weights.tif
# Adding empty weight file: 0474_weights.tif
# Adding empty weight file: 0475_weights.tif
# Adding empty weight file: 0476_weights.tif
# Adding empty weight file: 0477_weights.tif
# Adding empty weight file: 0478_weights.tif
# Adding empty weight file: 0479_weights.tif
# Adding empty weight file: 0480_weights.tif
# Adding empty weight file: 0481_weights.tif
# Adding empty weight file: 0482_weights.tif
# Adding empty weight file: 0483_weights.tif
# Adding empty weight file: 0484_weights.tif
# Adding empty weight file: 0485_weights.tif
# Adding empty weight file: 0486_weights.tif
# Adding empty weight file: 0487_weights.tif
# Adding empty weight file: 0488_weights.tif
# Adding empty weight file: 0489_weights.tif
# Adding empty weight file: 0490_weights.tif
# Adding empty weight file: 0491_weights.tif
# Adding empty weight file: 0492_weights.tif
# Adding empty weight file: 0493_weights.tif
# Adding empty weight file: 0494_weights.tif
# Adding empty weight file: 0495_weights.tif
# Adding empty weight file: 0496_weights.tif
# Adding empty weight file: 0497_weights.tif
# Adding empty weight file: 0498_weights.tif
# Adding empty weight file: 0499_weights.tif
# Channels.MASK set1/labels/0000_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0001_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0002_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0003_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0004_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0005_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0006_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0007_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0008_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0009_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0010_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0011_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0012_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0013_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0014_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0015_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0016_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0017_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0018_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0019_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0020_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0021_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0022_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0023_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0024_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0025_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0026_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0027_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0028_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0029_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0030_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0031_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0032_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0033_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0034_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0035_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0036_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0037_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0038_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0039_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0040_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0041_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0042_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0043_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0044_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0045_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0046_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0047_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0048_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0049_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0050_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0051_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0052_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0053_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0054_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0055_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0056_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0057_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0058_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0059_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0060_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0061_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0062_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0063_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0064_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0065_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0066_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0067_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0068_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0069_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0070_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0071_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0072_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0073_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0074_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0075_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0076_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0077_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0078_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0079_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0080_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0081_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0082_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0083_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0084_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0085_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0086_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0087_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0088_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0089_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0090_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0091_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0092_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0093_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0094_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0095_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0096_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0097_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0098_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0099_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0100_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0101_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0102_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0103_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0104_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0105_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0106_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0107_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0108_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0109_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0110_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0111_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0112_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0113_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0114_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0115_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0116_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0117_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0118_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0119_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0120_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0121_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0122_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0123_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0124_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0125_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0126_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0127_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0128_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0129_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0130_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0131_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0132_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0133_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0134_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0135_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0136_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0137_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0138_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0139_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0140_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0141_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0142_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0143_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0144_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0145_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0146_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0147_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0148_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0149_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0150_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0151_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0152_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0153_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0154_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0155_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0156_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0157_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0158_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0159_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0160_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0161_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0162_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0163_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0164_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0165_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0166_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0167_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0168_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0169_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0170_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0171_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0172_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0173_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0174_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0175_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0176_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0177_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0178_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0179_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0180_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0181_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0182_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0183_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0184_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0185_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0186_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0187_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0188_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0189_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0190_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0191_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0192_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0193_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0194_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0195_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0196_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0197_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0198_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0199_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0200_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0201_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0202_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0203_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0204_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0205_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0206_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0207_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0208_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0209_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0210_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0211_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0212_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0213_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0214_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0215_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0216_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0217_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0218_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0219_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0220_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0221_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0222_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0223_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0224_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0225_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0226_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0227_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0228_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0229_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0230_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0231_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0232_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0233_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0234_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0235_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0236_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0237_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0238_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0239_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0240_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0241_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0242_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0243_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0244_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0245_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0246_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0247_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0248_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0249_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0250_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0251_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0252_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0253_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0254_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0255_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0256_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0257_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0258_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0259_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0260_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0261_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0262_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0263_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0264_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0265_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0266_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0267_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0268_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0269_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0270_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0271_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0272_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0273_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0274_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0275_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0276_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0277_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0278_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0279_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0280_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0281_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0282_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0283_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0284_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0285_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0286_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0287_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0288_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0289_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0290_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0291_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0292_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0293_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0294_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0295_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0296_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0297_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0298_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0299_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0300_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0301_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0302_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0303_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0304_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0305_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0306_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0307_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0308_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0309_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0310_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0311_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0312_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0313_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0314_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0315_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0316_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0317_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0318_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0319_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0320_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0321_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0322_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0323_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0324_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0325_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0326_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0327_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0328_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0329_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0330_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0331_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0332_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0333_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0334_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0335_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0336_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0337_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0338_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0339_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0340_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0341_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0342_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0343_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0344_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0345_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0346_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0347_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0348_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0349_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0350_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0351_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0352_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0353_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0354_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0355_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0356_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0357_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0358_mask.tif.modified.tif (1024, 1024) uint8
# Channels.MASK set1/labels/0359_mask.tif.modified.tif (1024, 1024) uint8
# ...
# Channels.WEIGHTS set1/weights/0275_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0276_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0277_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0278_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0279_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0280_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0281_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0282_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0283_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0284_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0285_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0286_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0287_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0288_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0289_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0290_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0291_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0292_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0293_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0294_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0295_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0296_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0297_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0298_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0299_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0300_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0301_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0302_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0303_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0304_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0305_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0306_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0307_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0308_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0309_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0310_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0311_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0312_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0313_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0314_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0315_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0316_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0317_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0318_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0319_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0320_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0321_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0322_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0323_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0324_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0325_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0326_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0327_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0328_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0329_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0330_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0331_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0332_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0333_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0334_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0335_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0336_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0337_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0338_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0339_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0340_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0341_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0342_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0343_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0344_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0345_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0346_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0347_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0348_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0349_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0350_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0351_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0352_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0353_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0354_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0355_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0356_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0357_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0358_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0359_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0360_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0361_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0362_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0363_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0364_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0365_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0366_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0367_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0368_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0369_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0370_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0371_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0372_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0373_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0374_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0375_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0376_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0377_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0378_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0379_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0380_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0381_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0382_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0383_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0384_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0385_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0386_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0387_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0388_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0389_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0390_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0391_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0392_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0393_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0394_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0395_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0396_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0397_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0398_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0399_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0400_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0401_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0402_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0403_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0404_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0405_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0406_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0407_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0408_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0409_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0410_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0411_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0412_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0413_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0414_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0415_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0416_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0417_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0418_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0419_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0420_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0421_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0422_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0423_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0424_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0425_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0426_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0427_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0428_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0429_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0430_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0431_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0432_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0433_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0434_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0435_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0436_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0437_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0438_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0439_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0440_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0441_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0442_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0443_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0444_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0445_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0446_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0447_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0448_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0449_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0450_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0451_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0452_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0453_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0454_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0455_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0456_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0457_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0458_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0459_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0460_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0461_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0462_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0463_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0464_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0465_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0466_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0467_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0468_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0469_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0470_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0471_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0472_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0473_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0474_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0475_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0476_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0477_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0478_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0479_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0480_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0481_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0482_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0483_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0484_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0485_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0486_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0487_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0488_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0489_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0490_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0491_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0492_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0493_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0494_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0495_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0496_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0497_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0498_weights.tif (1024, 1024, 3) float32
# Channels.WEIGHTS set1/weights/0499_weights.tif (1024, 1024, 3) float32

# %%
def normalize_images(stack):
    normed = stack.astype(np.float32)
    
    for i in range(stack.shape[0]):
        # normed[i,...] = (normed[i,...]-np.mean(normed[i,...])) / np.std(normed[i,...])
        c = normed[i,...]
        p_lo = np.percentile(c,5)
        p_hi = np.percentile(c,99)
        normed[i,...] = np.clip((c - p_lo) / p_hi, 0., 1.)
    return normed

# %%
def bounding_boxes(seg):
    lbl, nlbl = ndimage.label(seg)
    class_label, _, minxy, maxxy = ndimage.extrema(seg, lbl, index=np.arange(1, nlbl+1))
    return class_label, minxy, maxxy

# %%
seg = np.zeros(data[channels[0]]['data'].shape, dtype=np.uint8)
mask = data[Channels.MASK]['data']
if mask.ndim == 3:
    seg = mask > 0
elif mask.ndim == 4:
    seg[mask[:,0,...]>0] = 1
    seg[mask[:,1,...]>0] = 2

# %%
def convert_to_mask(labels, unique_labels=range(1,len(channels)+1)):
    print(unique_labels)
    seg = np.zeros((len(unique_labels),)+labels.shape, dtype=np.uint8)
    for i,l in enumerate(unique_labels):
        seg[i,...] = labels==l
    return np.squeeze(seg)

# %%
def save_labels(viewer):
    # get the current image 
    current_slice = viewer.layers[viewer.active_layer].coordinates[0]
    source_set = data[Channels.MASK]['sets'][current_slice]
    source_file = data[Channels.MASK]['files'][current_slice]
    source_fn = os.path.join(source_set, 'labels', source_file)

    # get the current layer
    current_labels = viewer.layers['labels'].data[current_slice,...]
    current_mask = convert_to_mask(current_labels)

    # write out the modified segmentation mask
    new_file = os.path.join(DATA_PATH, source_fn+'.modified.tif')
    print(new_file)
    io.imsave(new_file, current_mask[0].astype('uint8'))

    print(current_slice, current_labels.shape, new_file)

# %%
def save_all_labels(viewer):
        # get the current image 
    current_slice = viewer.layers[viewer.active_layer].coordinates[0]
    #current_slice = viewer.layers[viewer.active_layer].coordinates[1] # prints the x coord
    
    source_set = data[Channels.MASK]['sets'][current_slice]
    source_file = data[Channels.MASK]['files'][current_slice]
    source_fn = os.path.join(source_set, 'labels', source_file)

    # get the current layer
    current_labels = viewer.layers['labels'].data[current_slice,...]
    current_mask = convert_to_mask(current_labels)
    
    for i in range(viewer.layers['labels'].data.shape[0]):
        current_slice = i
        
        source_set = data[Channels.MASK]['sets'][current_slice]
        source_file = data[Channels.MASK]['files'][current_slice]
        source_fn = os.path.join(source_set, 'labels', source_file)
        
        current_labels = viewer.layers['labels'].data[current_slice,...]
        current_mask = convert_to_mask(current_labels)
        
        new_file = os.path.join(DATA_PATH, source_fn+'.modified.tif')

        io.imsave(new_file, current_mask[0].astype('uint8'))

        print(current_slice, current_labels.shape, new_file)

# %%
# weightmaps = np.zeros((seg.shape), dtype=np.float32)

def calculate_weightmaps(viewer, w0=WEIGHT_AMPLITUDE, current_slice=0):
    # get the current layer and make it binary
    mask = viewer.layers['labels'].data[current_slice,...].astype(np.bool)
    
    # label the image 
    labelled, n_labels = ndimage.label(mask)
    #print(n_labels)
    weight_mask = np.zeros(mask.shape, dtype=np.float32)
    for i in range(1,n_labels+1):
        cell = labelled == i
        not_cell = np.logical_xor(cell, mask) #np.logical_and(labelled != i, labelled > 0)
        mask_diff = gaussian_filter(cell.astype(np.float32), sigma=5) * gaussian_filter(not_cell.astype(np.float32), sigma=5)
        weight_mask += mask_diff

    wmap = w0*weight_mask #* wmap
    
    # normalize it
    wmap += 1.   
    wmap[mask] = 1.
      
    viewer.layers['weightmaps'].data[current_slice,...] = wmap.astype(np.float32)
    viewer.layers['weightmaps'].contrast_limits = (np.min(wmap), np.max(wmap))
    viewer.layers['weightmaps'].visible = True
    
    return wmap

# %%
# secondary weighting = weightmap * weightmask
# purpose is to create a secondary weightmap that can be used to tell the network to focus/ignore on user-selected ROIs

def calculate_custom_weightmap(viewer, current_slice=0):
    
    if "custom weightmap" not in str(viewer.layers): #this checks if the custom weightmap layer exists, and if it doesnt it creates one for it
        cust_wmap = data[Channels.WEIGHTS]['data']
        viewer.add_image(cust_wmap, name='custom weightmap', colormap='plasma', visible=False)
    
    w_mask = viewer.layers['weightmask'].data[current_slice,...].astype(np.bool)
    w_map =  viewer.layers['weightmaps'].data[current_slice,...]   
    cust_wmap = w_map*w_mask
  
    viewer.layers['custom weightmap'].data[current_slice,...] = cust_wmap.astype(np.float32) # need this line to 
    viewer.layers['custom weightmap'].contrast_limits = (np.min(cust_wmap), np.max(cust_wmap))
    viewer.layers['custom weightmap'].visible = True
    
    return cust_wmap

# %%
def grow_shrink_label(viewer, grow=True, n_iter=1): #by editing the number of iterations i can edit the size of growshrink
    current_slice = viewer.layers[viewer.active_layer].coordinates[0]
    current_labels = viewer.layers['labels'].data[current_slice,...] #label as in image
            
    cursor_coords = [int(p) for p in viewer.layers[viewer.active_layer].position]
    labelled, _ = ndimage.label(current_labels.astype(np.bool)) #each obj in label image is labelled
    real_label = current_labels[cursor_coords[0], cursor_coords[1]] #xy cursor coords in current label image
    
    if real_label < 1: return
    
    mask = labelled == labelled[cursor_coords[0], cursor_coords[1]] #assigning mask as labelled image with only xy of specific cell
    if grow:
        mask = ndimage.morphology.binary_dilation(mask, iterations=n_iter)   
    else:
        current_labels[mask] = 0
        mask = ndimage.morphology.binary_erosion(mask, iterations=n_iter)
    current_labels[mask] = real_label
    viewer.layers['labels'].data[current_slice,...] = current_labels
    viewer.layers['labels']._set_view_slice()

# %%
def count_cells(viewer):
    current_slice = viewer.layers[viewer.active_layer].coordinates[0]
    mask = viewer.layers['labels'].data[current_slice,...].astype(np.bool) 
    labelled, n_labels = ndimage.label(mask)
       
    stat_file = os.path.join(DATA_PATH, 'stats.csv')
    
    i=0
    df=pd.DataFrame(data=[0], index=[i], columns=['number of cells'])
    
    for i in range(viewer.layers['labels'].data.shape[0]):
        current_slice = i
        mask = viewer.layers['labels'].data[current_slice,...].astype(np.bool) 
        labelled, n_labels = ndimage.label(mask)
        
        
            
        df.loc[i] = n_labels
        df.to_csv(stat_file, index=False)
    print(df)

# %%
def measure(viewer): #for single cell trajectories, add another iterative loop when wanting all cell trajectories
    current_slice = viewer.layers[viewer.active_layer].coordinates[0]
    mask = viewer.layers['labels'].data[current_slice,...].astype(np.bool) 
    labelled, n_labels = ndimage.label(mask)
    for s in sets:
        dirName = os.path.join(DATA_PATH, s, 'results')
        try:
            # Create target Directory
            os.mkdir(dirName)
            print("Directory " , dirName ,  " Created ") 
        except FileExistsError:
            print("Directory " , dirName ,  " already exists")
    
        stat_file_dir = os.path.join(dirName, 'image_numbers_' + str(INDEX_OF_IMAGES))
        
        try:
            # Create target Directory
            os.mkdir(stat_file_dir)
            print("Directory " , stat_file_dir ,  " Created ") 
        except FileExistsError:
            print("Directory " , stat_file_dir ,  " already exists")
        os.mkdir()
        stat_file = os.path.join(stat_file_dir, 'stats.csv')
    
        i=0
        df = pd.DataFrame([], index=[i], columns=['GFP Intensity', 'RFP Intensity', 'Phase Intensity', 'Area', 'x','y']) #is this assignment of df correct? or does it overwrite "count_cells" above

        for i in range(viewer.layers['labels'].data.shape[0]):
            current_slice = i
            mask = viewer.layers['labels'].data[current_slice,...].astype(np.bool) 
            labelled, n_labels = ndimage.label(mask)

            gfp = viewer.layers['GFP'].data[current_slice,...]
            gfp_pix_value = ndimage.sum(gfp, labelled, 1) 
            #need way of linking labelled cell identities to tracks --> centroid?

            rfp = viewer.layers['RFP'].data[current_slice,...]
            rfp_pix_value = ndimage.sum(rfp, labelled, 1)

            phase = viewer.layers['Phase'].data[current_slice,...]
            phase_pix_value = ndimage.sum(phase, labelled, 1) # == ndimage.sum(mask*phase)

            df.loc[i,'GFP Intensity'] = gfp_pix_value 
            df.loc[i,'RFP Intensity'] = rfp_pix_value
            df.loc[i,'Phase Intensity'] = phase_pix_value 
            df.loc[i,'Area'] = ndimage.sum(mask)
            #df.loc[i,'Max'] =  ndimage.maximum(phase, labelled)

            centroid = ndimage.measurements.center_of_mass(mask)
            y = centroid[0]
            x = centroid[1]
            df.loc[i,'x'] = format(x, '.2f')
            df.loc[i,'y'] = format(y, '.2f')

            df.to_csv(stat_file, index=False)
        print(df)
        print('2468-never-too-late, I counted all them cells THANK U')

# %%
def fill_holes(viewer):
    current_slice = viewer.layers[viewer.active_layer].coordinates[0]
    current_labels = viewer.layers['labels'].data[current_slice,...] #label as in image
            
    cursor_coords = [int(p) for p in viewer.layers[viewer.active_layer].position]
    labelled, _ = ndimage.label(current_labels.astype(np.bool)) #each obj in label image is labelled
    real_label = current_labels[cursor_coords[0], cursor_coords[1]] #xy cursor coords in current label image
    
    if real_label < 1: return
    
    mask = labelled == labelled[cursor_coords[0], cursor_coords[1]] #assigning mask as labelled image with only xy of specific cell
    mask = ndimage.morphology.binary_fill_holes(mask) 
    current_labels[mask] = real_label
    viewer.layers['labels'].data[current_slice,...] = current_labels
    viewer.layers['labels']._set_view_slice()

# %%
def single_cell_mask(viewer):  #by editing the number of iterations i can edit the size of growshrink
    # get the current image 
    current_slice = viewer.layers[viewer.active_layer].coordinates[0]
    current_labels = viewer.layers['labels'].data[current_slice,...] #label as in image
    
        
    cursor_coords = [int(p) for p in viewer.layers[viewer.active_layer].position]
    labelled, _ = ndimage.label(current_labels.astype(np.bool)) #each obj in label image is labelled
    real_label = current_labels[cursor_coords[0], cursor_coords[1]] #xy cursor coords in current label image
    
    if real_label < 1: return
    
    mask = labelled == labelled[cursor_coords[0], cursor_coords[1]] #assigning mask as labelled image with only xy of specific cell
    
    current_labels = mask    
    viewer.layers['labels'].data[current_slice,...] = current_labels
    viewer.layers['labels']._set_view_slice()

# %%
def fluorescent_noise(viewer):
    pth = DATA_PATH
    for s in sets:
        #label_files = [f for f in os.listdir(l_root) if f.endswith('.tif')]
        l_root = os.path.join(pth, s, 'labels')
        label_files = [f for f in os.listdir(l_root) if f.endswith('.tif')]
        #add input for gfp and rfp
        channels = [Channels[c.upper()] for c in INCOMPLETE_CHANNELS]
        incomplete_files = {k:{'files':[], 'data':[], 'sets':[], 'path':[]} for k in channels} #need to add something like this to include Channels.GFP etc in files[channels]        
        files.update(incomplete_files) #merging two dicts to create complete file dict
        for channel in channels:
                #if cfiles channel.name.lower dir doesnt contain gfp or rfp then add option to create noise data,
                channel_dir = os.path.join(pth, s, channel.name.lower())            
                if os.path.exists(channel_dir): #if fluor/phase channels exist, continue as norm
                    cfiles = [fnfmt(l, channel.name.lower()) for l in label_files]                  
                    files[channel]['path'] += [s+'/'+channel.name.lower()+'/'+f for f in cfiles]
                    files[channel]['files'] += cfiles #filenames
                    files[channel]['data'] += [io.imread(os.path.join(pth, s, channel.name.lower(), f)) for f in cfiles] #actualdata
                    files[channel]['sets'] += [s] * len(label_files)
                    
                else: #if fluor ch missing then create one and fill it with noise - 
                    os.mkdir(channel_dir) #create fl ch dir
                    cfiles = [fnfmt(l, channel.name.lower()) for l in label_files]
                    files[channel]['path'] += [s+'/'+channel.name.lower()+'/'+f for f in cfiles]
                    files[channel]['files'] += cfiles #filenames 
                    files[channel]['sets'] += [s] * len(label_files)
                    
                    for f in cfiles:
                        print(f'Adding gaussian noise fluorescence file: {f}')             
                        #shape = [files[channels[0]]['data'][0].shape]
                        random = np.random.normal(loc=((2^32)/2), scale=((2^32)/2), size=shape) #(1024,1024)) what is the stdev of an 8bit image?
                        ### need to check if this is really the best way of generating a random image
                        random_path = os.path.join(channel_dir, f)
                        io.imsave(random_path, random.astype(np.float32))
                                            
                    files[channel]['data'] += [io.imread(os.path.join(pth, s, channel.name.lower(), f)) for f in cfiles] #reads image from disk and adds it to dict 
                                       
    print("I AM DONE, THANK YOU VERY MUCH")

# %%
# start napari
with napari.gui_qt():
    viewer = napari.Viewer()
    
    if Channels.GFP in data:
        #gfp = normalize_images(data[Channels.GFP]['data'])
        gfp = data[Channels.GFP]['data']
        viewer.add_image(gfp, name='GFP', colormap='green')#, contrast_limits=(0.,1.))
        
    if Channels.RFP in data:
        #rfp = normalize_images(data[Channels.RFP]['data'])
        rfp = data[Channels.RFP]['data']
        viewer.add_image(rfp, name='RFP', colormap='magenta')#, contrast_limits=(0.,1.))
        viewer.layers['RFP'].blending = 'additive'
        
    if Channels.PHASE in data:
        #phase = normalize_images(data[Channels.PHASE]['data'])
        phase = data[Channels.PHASE]['data']
        viewer.add_image(phase, name='Phase', colormap='gray')
    
    if Channels.WEIGHTS in data:
        weightmaps = data[Channels.WEIGHTS]['data']
        viewer.add_image(weightmaps, name='weightmaps', colormap='plasma', visible=False)
        
    """if Channels.WEIGHTS in data:
        cust_wmap = data[Channels.WEIGHTS]['data']
        viewer.add_image(cust_wmap, name='custom weightmap', colormap='plasma', visible=False)"""
    
    viewer.add_labels(seg, name='labels')
    viewer.layers['labels'].opacity = 0.4
    viewer.layers['weightmaps'].blending = 'additive'
    
    weight_mask = np.ones(data[Channels.WEIGHTS]['data'].shape, dtype=np.uint8)
    #cust_wmap = np.ones(data[Channels.WEIGHTS]['data'].shape, dtype=np.uint8)
    viewer.add_labels(weight_mask, name='weightmask', visible=False)
    #viewer.add_image(cust_wmap, name='custom weightmap', colormap='plasma', visible=False)

    @viewer.bind_key('g') #try capitalising this bind key to avoid accidental pressing
    def k_fluorescent_noise(viewer):
        print("Creating simulated fluorescence channels with gaussian noise")
        fluorescent_noise(viewer) 
            
    @viewer.bind_key('/') #double command
    def k_save_labels(viewer):
        save_labels(viewer)  #need to change the (viewer) bit to save all images   
        
    @viewer.bind_key('s')
    def k_save_all_labels(viewer):
        save_all_labels(viewer)
        
    @viewer.bind_key('n')
    def k_count_cells(viewer):
        count_cells(viewer)
        
    @viewer.bind_key('m')
    def k_measure(viewer):
        measure(viewer)
        
    @viewer.bind_key('w')
    def k_calculate_weightmaps(viewer):
        current_slice = viewer.layers[viewer.active_layer].coordinates[0]
        calculate_weightmaps(viewer, current_slice=current_slice)
        ## calculate cust_ here?
        
    @viewer.bind_key('q')
    def k_calculate_custom_weightmap(viewer):
        current_slice = viewer.layers[viewer.active_layer].coordinates[0]
        calculate_custom_weightmap(viewer, current_slice=current_slice)
        
    @viewer.bind_key('<')
    def k_shrink_label(viewer):
        print('shrink label')
        grow_shrink_label(viewer, grow=False)
    
    @viewer.bind_key('>') 
    def k_grow_label(viewer):
        print('grow label')
        grow_shrink_label(viewer, grow=True)
        
    @viewer.bind_key('0') #clear @viewer.bind_key('c')
    def k_single_cell(viewer):
        print('select cell')
        single_cell_mask(viewer)
        
    @viewer.bind_key('c') #clear @viewer.bind_key('c')
    def k_single_cell(viewer):
        print('select cell')
        single_cell_mask(viewer)
        
    @viewer.bind_key('h') #fill holes in cell masks
    def k_fill_holes(viewer):
        print('filling holes in cell mask')
        fill_holes(viewer) 
    
    @viewer.bind_key('o')
    def k_output(viewer):
        print('Output all with metadata')
                
        for i in range(viewer.layers['weightmaps'].data.shape[0]):
            
            if np.sum(viewer.layers['weightmaps'].data[i,...]) == 0: # get rid of this condition to calculate weightmaps afresh regardless?
                print(f'Weightmap {i} is empty. Calculating...')
                wmap = calculate_weightmaps(viewer, current_slice=i)
                weight_folder = os.path.join(DATA_PATH, data[Channels.WEIGHTS]['sets'][i], 'weights')
                weight_fn = data[Channels.WEIGHTS]['files'][i]
                print(weight_folder, weight_fn)
                make_folder(weight_folder)
                io.imsave(os.path.join(weight_folder, weight_fn), wmap.astype(np.float32))
          
                #write out cust_weight_map too
                
                cust_wmap = calculate_custom_weightmap(viewer, current_slice=i)
                cust_weight_folder = os.path.join(DATA_PATH, data[Channels.WEIGHTS]['sets'][i], 'custom_weights')       
                #os.path.join((data[Channels.WEIGHTS]['files'][i][:+]),'.custom.tif')
                cust_weight_fn = data[Channels.WEIGHTS]['files'][i] ##add custom to this fn!!!!!!!!!!!! or do i want to keep fn as before for forward compatability?
                print(cust_weight_folder, cust_weight_fn)
                make_folder(cust_weight_folder)
                io.imsave(os.path.join(cust_weight_folder, cust_weight_fn), cust_wmap.astype(np.float32))
                
                ## adding save out of the weight masks
                w_mask = viewer.layers['weightmask'].data[i,...].astype(np.bool)                
                weight_mask_folder = os.path.join(DATA_PATH, data[Channels.WEIGHTS]['sets'][i], 'weight_masks')
                weight_mask_fn = data[Channels.MASK]['files'][i] ##add weight to fn
                print(weight_mask_folder, weight_mask_fn)
                make_folder(weight_mask_folder)
                io.imsave(os.path.join(weight_mask_folder, weight_mask_fn), w_mask.astype(np.float32))
                
                
        # write out a JSON file with the data
        jfn = os.path.join(DATA_PATH, 'training_metadata.json')
        jdata = {}
        for channel in data.keys():
            jdata[channel.name.lower()] = data[channel]['path'] 
            
        with open(jfn, 'w') as json_file:
            json.dump(jdata, json_file, indent=2, separators=(',', ': '))

# %%
# # convert segmentation output labels to multichannel stacks

# p = '/Users/arl/Dropbox/Data/TrainingData/set12'
# files = [f for f in os.listdir(os.path.join(p,'labels')) if f.endswith('.tif')]
# for f in files:
#     mask = io.imread(os.path.join(p, 'labels', f))
#     print(mask.shape)
#     gfp = mask==1
#     rfp = mask==2
#     new_mask = np.stack([gfp, rfp], axis=0)
#     io.imsave(os.path.join(p,f), new_mask.astype('uint8'))
