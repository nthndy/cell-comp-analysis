 1, 1, 1, 70, 14, 1, 18, 3, 12, 172, 112, 494, 10, 1, 1, 1, 5, 1, 1, 3, 26, 4, 1, 1, 423, 1, 5, 3, 1, 495, 4, 1, 1, 224, 1, 42, 1, 20, 1, 6, 3, 599, 1, 1, 2, 1, 4, 1, 6, 3, 607, 7, 140, 1, 1, 51, 7, 1, 23, 1, 4, 1, 2, 2, 1, 3, 1, 1, 1, 1, 1, 9, 2, 1, 3, 2, 55, 7, 1, 10, 1, 2, 1, 1, 537, 4, 1, 7, 1, 1, 12, 1, 1, 157, 1, 16, 3, 2, 3, 4, 1, 7, 3, 1, 71, 29, 580, 58, 6, 2, 1, 7, 1, 2, 1, 86, 16, 46, 85, 639, 1, 2, 1, 21, 1, 62, 19, 16, 3, 13, 60, 2, 2, 1, 1, 1, 1, 26, 1, 20, 6, 24, 1, 5, 21, 1, 1, 1, 1, 1, 14, 13, 33, 3, 1, 2, 1, 181, 492, 3, 324, 3, 1, 4, 4, 13, 47, 4, 1, 193, 1, 1, 7, 1, 1, 22, 16, 19, 3, 1, 1, 3, 1, 9, 5, 79, 301, 79, 33, 46, 5, 5, 5, 15, 1, 4, 5, 19, 7, 7, 2, 1, 17, 6, 5, 1, 2, 85, 5, 1, 1, 27, 1, 4, 4, 2, 1, 2, 579, 3, 1, 1, 84, 4, 1, 3, 1, 196, 2, 1, 284, 1, 1, 56, 103, 7, 2, 1, 1, 67, 70, 7, 2, 1, 606, 82, 34, 1, 153, 1, 1, 2, 4, 1, 1, 260, 2, 1, 1, 1, 3, 47, 13, 1, 1, 1, 1, 12, 8, 4, 25, 6, 1, 1, 1, 1, 1, 13, 71, 4, 28, 9, 2, 1, 1, 2, 398, 2, 4, 3, 4, 4, 1, 1, 4, 1, 2, 1, 8, 804, 368, 3, 441, 32, 2, 1, 466, 32, 4, 1, 12, 4, 1, 9, 13, 5, 1, 1, 183, 254, 2, 5, 294, 9, 4, 60, 28, 4, 3, 15, 5, 1, 3, ...

# %% [markdown]
# ## Get the tracks

# %%
# NOTE(arl):  This should be from your image segmentation code
objects = import_HDF('/home/nathan/data/fucci/HDF/segmented.hdf5', filter_using=None)


print(objects)
# initialise a tracker session using a context manager
with btrack.BayesianTracker() as tracker:

  # configure the tracker using a config file
  tracker.configure_from_file('/home/nathan/analysis/BayesianTracker/models/cell_config_1.json')

  # append the objects to be tracked
  tracker.append(objects)

  # set the volume (Z axis volume is set very large for 2D data)
  tracker.volume=((0,1024),(0,1024),(-1e5,1e5))

  # track them (in interactive mode)
  tracker.track_interactive(step_size=100)

  # generate hypotheses and run the global optimiser
  tracker.optimize()

  # get the tracks as a python list
  tracks = tracker.tracks
# Out:
# [INFO][2020/06/03 01:50:35 PM] Opening HDF file: /home/nathan/data/fucci/HDF/segmented.hdf5
# [WARNING][2020/06/03 01:50:35 PM] Labels missing from objects in HDF file
# [INFO][2020/06/03 01:50:35 PM] Loading obj_type_1 (243739, 5) (243739 filtered: None)...
# [INFO][2020/06/03 01:50:39 PM] Closing HDF file: /home/nathan/data/fucci/HDF/segmented.hdf5
# [INFO][2020/06/03 01:50:39 PM] btrack (v0.3.7) library imported
# [INFO][2020/06/03 01:50:39 PM] Starting BayesianTracker session
# [INFO][2020/06/03 01:50:39 PM] Loading configuration file: /home/nathan/analysis/BayesianTracker/models/cell_config_1.json
# [INFO][2020/06/03 01:50:39 PM] Loading motion model: b'cell_motion'
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# [INFO][2020/06/03 01:50:40 PM] Set volume to ((0, 1024), (0, 1024), (-100000.0, 100000.0))
# [INFO][2020/06/03 01:50:40 PM] Starting tracking...
# [INFO][2020/06/03 01:50:40 PM] Tracking objects in frames 0 to 99 (of 1093)...
# [INFO][2020/06/03 01:50:41 PM]  - Timing (Bayesian updates: 19.51ms, Linking: 1.09ms)
# [INFO][2020/06/03 01:50:41 PM]  - Probabilities (Link: 0.99277, Lost: 1.00000)
# [INFO][2020/06/03 01:50:41 PM]  - Stats (Active: 260, Lost: 5259, Conflicts resolved: 1861)
# [INFO][2020/06/03 01:50:41 PM] Tracking objects in frames 100 to 199 (of 1093)...
# [INFO][2020/06/03 01:50:44 PM]  - Timing (Bayesian updates: 22.30ms, Linking: 1.53ms)
# [INFO][2020/06/03 01:50:44 PM]  - Probabilities (Link: 0.52173, Lost: 0.98540)
# [INFO][2020/06/03 01:50:44 PM]  - Stats (Active: 248, Lost: 10019, Conflicts resolved: 3591)
# [INFO][2020/06/03 01:50:44 PM] Tracking objects in frames 200 to 299 (of 1093)...
# [INFO][2020/06/03 01:50:46 PM] Ending BayesianTracker session
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-1e45f5ae9013> in <module>
#      17
#      18   # track them (in interactive mode)
# ---> 19   tracker.track_interactive(step_size=100)
#      20
#      21   # generate hypotheses and run the global optimiser
#
# ~/anaconda3/lib/python3.7/site-packages/btrack/core.py in track_interactive(self, step_size)
#     445                 self._frame_range[1]+1), self._frame_range[1]+1))
#     446
# --> 447             stats = self.step(step_size)
#     448             utils.log_stats(stats.to_dict())
#     449             frm+=step_size
#
# ~/anaconda3/lib/python3.7/site-packages/btrack/core.py in step(self, n_steps)
#     462         interactive mode tracking """
#     463         if not self._initialised: return None
# --> 464         return self._stats(lib.step( self._engine, n_steps ))
#     465
#     466
#
# KeyboardInterrupt:

# %%
# get the first track
track_zero = tracks[0]

# print the length of the track
print(len(track_zero))

# print all of the xyzt positions in the track
print(track_zero.x)
print(track_zero.y)
print(track_zero.z)
print(track_zero.t)

# print the fate of the track
print(track_zero.fate)

# print the track ID, root node, parent node and children
print(track_zero.ID)
print(track_zero.root)
print(track_zero.parent)
print(track_zero.children)

# %% [markdown]
# ### visualize the tracks

# %%
### length of tracks 
for i in range(len(tracks)):
    print("track no.",i,"length=", len(tracks[i]))

# %%
mpl.rcParams['legend.fontsize'] = 10


fig = plt.figure()
ax = fig.gca(projection='3d')

track_34 = tracks[51]
z = list(range(len(track_34)))

x = track_34.x
y = track_34.y
ax.plot(x, y, z, label='track_34')
ax.legend()

plt.show()

# %% [markdown]
# # output .hdf5

# %%
fn = '/home/nathan/analysis/BayesianTracker/examples/segmented_v5.hdf5'
tracker.export(fn,obj_type='obj_type_1')

# %% [markdown]
# # do all of the above

# %%
import btrack
from btrack.utils import import_HDF
from btrack.utils import import_JSON

import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import numpy as np

# NOTE(arl):  This should be from your image segmentation code
objects = import_HDF('/home/nathan/data/fucci/HDF/segmented.hdf5')

print(objects)
# initialise a tracker session using a context manager
with btrack.BayesianTracker() as tracker:

    # configure the tracker using a config file
    tracker.configure_from_file('/home/nathan/analysis/BayesianTracker/models/cell_config_1.json')

    # append the objects to be tracked
    tracker.append(objects)

    # set the volume (Z axis volume is set very large for 2D data)
    tracker.volume=((0,1024),(0,1024),(-1e5,1e5))

    # track them (in interactive mode)
    tracker.track_interactive(step_size=100)

    # generate hypotheses and run the global optimiser
    tracker.optimize()

    # get the tracks as a python list
    tracks = tracker.tracks

    fn = '/home/nathan/data/fucci/HDF/segmented.hdf5'
    tracker.export(fn,obj_type='obj_type_1')
    
    print("tick")
# Out:
# [INFO][2020/06/03 01:50:59 PM] Opening HDF file: /home/nathan/data/fucci/HDF/segmented.hdf5
# [WARNING][2020/06/03 01:50:59 PM] Labels missing from objects in HDF file
# [INFO][2020/06/03 01:50:59 PM] Loading obj_type_1 (243739, 5) (243739 filtered: None)...
# [INFO][2020/06/03 01:51:02 PM] Closing HDF file: /home/nathan/data/fucci/HDF/segmented.hdf5
# [INFO][2020/06/03 01:51:02 PM] btrack (v0.3.7) library imported
# [INFO][2020/06/03 01:51:02 PM] Starting BayesianTracker session
# [INFO][2020/06/03 01:51:02 PM] Loading configuration file: /home/nathan/analysis/BayesianTracker/models/cell_config_1.json
# [INFO][2020/06/03 01:51:02 PM] Loading motion model: b'cell_motion'
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# [INFO][2020/06/03 01:51:02 PM] Set volume to ((0, 1024), (0, 1024), (-100000.0, 100000.0))
# [INFO][2020/06/03 01:51:02 PM] Starting tracking...
# [INFO][2020/06/03 01:51:02 PM] Tracking objects in frames 0 to 99 (of 1093)...
# [INFO][2020/06/03 01:51:04 PM]  - Timing (Bayesian updates: 16.81ms, Linking: 0.95ms)
# [INFO][2020/06/03 01:51:04 PM]  - Probabilities (Link: 0.99277, Lost: 1.00000)
# [INFO][2020/06/03 01:51:04 PM]  - Stats (Active: 260, Lost: 5259, Conflicts resolved: 1861)
# [INFO][2020/06/03 01:51:04 PM] Tracking objects in frames 100 to 199 (of 1093)...
# [INFO][2020/06/03 01:51:05 PM]  - Timing (Bayesian updates: 15.61ms, Linking: 1.10ms)
# [INFO][2020/06/03 01:51:05 PM]  - Probabilities (Link: 0.52173, Lost: 0.98540)
# [INFO][2020/06/03 01:51:05 PM]  - Stats (Active: 248, Lost: 10019, Conflicts resolved: 3591)
# [INFO][2020/06/03 01:51:05 PM] Tracking objects in frames 200 to 299 (of 1093)...
# [INFO][2020/06/03 01:51:07 PM]  - Timing (Bayesian updates: 25.85ms, Linking: 1.31ms)
# [INFO][2020/06/03 01:51:07 PM]  - Probabilities (Link: 0.99999, Lost: 1.00000)
# [INFO][2020/06/03 01:51:07 PM]  - Stats (Active: 245, Lost: 14123, Conflicts resolved: 5050)
# [INFO][2020/06/03 01:51:07 PM] Tracking objects in frames 300 to 399 (of 1093)...
# [INFO][2020/06/03 01:51:09 PM]  - Timing (Bayesian updates: 16.36ms, Linking: 1.22ms)
# [INFO][2020/06/03 01:51:09 PM]  - Probabilities (Link: 1.00000, Lost: 1.00000)
# [INFO][2020/06/03 01:51:09 PM]  - Stats (Active: 259, Lost: 18246, Conflicts resolved: 6531)
# [INFO][2020/06/03 01:51:09 PM] Tracking objects in frames 400 to 499 (of 1093)...
# [INFO][2020/06/03 01:51:11 PM]  - Timing (Bayesian updates: 16.31ms, Linking: 0.88ms)
# [INFO][2020/06/03 01:51:11 PM]  - Probabilities (Link: 0.98842, Lost: 1.00000)
# [INFO][2020/06/03 01:51:11 PM]  - Stats (Active: 247, Lost: 23008, Conflicts resolved: 8187)
# [INFO][2020/06/03 01:51:11 PM] Tracking objects in frames 500 to 599 (of 1093)...
# [INFO][2020/06/03 01:51:13 PM]  - Timing (Bayesian updates: 21.64ms, Linking: 1.28ms)
# [INFO][2020/06/03 01:51:13 PM]  - Probabilities (Link: 1.00000, Lost: 1.00000)
# [INFO][2020/06/03 01:51:13 PM]  - Stats (Active: 319, Lost: 29020, Conflicts resolved: 10454)
# [INFO][2020/06/03 01:51:13 PM] Tracking objects in frames 600 to 699 (of 1093)...
# [INFO][2020/06/03 01:51:16 PM]  - Timing (Bayesian updates: 26.56ms, Linking: 1.61ms)
# [INFO][2020/06/03 01:51:16 PM]  - Probabilities (Link: 0.99960, Lost: 1.00000)
# [INFO][2020/06/03 01:51:16 PM]  - Stats (Active: 322, Lost: 35688, Conflicts resolved: 12989)
# [INFO][2020/06/03 01:51:16 PM] Tracking objects in frames 700 to 799 (of 1093)...
# [INFO][2020/06/03 01:51:19 PM]  - Timing (Bayesian updates: 31.41ms, Linking: 1.40ms)
# [INFO][2020/06/03 01:51:19 PM]  - Probabilities (Link: 1.00000, Lost: 1.00000)
# [INFO][2020/06/03 01:51:19 PM]  - Stats (Active: 341, Lost: 42489, Conflicts resolved: 15827)
# [INFO][2020/06/03 01:51:19 PM] Tracking objects in frames 800 to 899 (of 1093)...
# [INFO][2020/06/03 01:51:23 PM]  - Timing (Bayesian updates: 33.21ms, Linking: 1.50ms)
# [INFO][2020/06/03 01:51:23 PM]  - Probabilities (Link: 1.00000, Lost: 0.99988)
# [INFO][2020/06/03 01:51:23 PM]  - Stats (Active: 349, Lost: 48846, Conflicts resolved: 18417)
# [INFO][2020/06/03 01:51:23 PM] Tracking objects in frames 900 to 999 (of 1093)...
# [INFO][2020/06/03 01:51:27 PM]  - Timing (Bayesian updates: 34.98ms, Linking: 1.41ms)
# [INFO][2020/06/03 01:51:27 PM]  - Probabilities (Link: 1.00000, Lost: 1.00000)
# [INFO][2020/06/03 01:51:27 PM]  - Stats (Active: 353, Lost: 56049, Conflicts resolved: 21320)
# [INFO][2020/06/03 01:51:27 PM] Tracking objects in frames 1000 to 1093 (of 1093)...
# [INFO][2020/06/03 01:51:31 PM]  - Timing (Bayesian updates: 33.85ms, Linking: 1.69ms)
# [INFO][2020/06/03 01:51:31 PM]  - Probabilities (Link: 0.99961, Lost: 0.99999)
# [INFO][2020/06/03 01:51:31 PM] SUCCESS.
# [INFO][2020/06/03 01:51:31 PM]  - Found 12870 tracks in 1093 frames (in 0.0s)
# [INFO][2020/06/03 01:51:31 PM]  - Inserted 18071 dummy objects to fill tracking gaps
# [INFO][2020/06/03 01:51:31 PM] Loading hypothesis model: cell_hypothesis_0.01_miss
# [INFO][2020/06/03 01:51:31 PM] Calculating hypotheses from tracklets...
# [INFO][2020/06/03 01:51:31 PM] Setting up constraints matrix for global optimisation...
# [INFO][2020/06/03 01:51:33 PM] Optimising...
# [INFO][2020/06/03 01:51:49 PM] Optimisation complete. (Solution: optimal)
# [INFO][2020/06/03 01:51:49 PM]  - Fates.INITIALIZE_BORDER: 5146 (of 12648)
# [INFO][2020/06/03 01:51:49 PM]  - Fates.TERMINATE_BORDER: 5591 (of 12539)
# [INFO][2020/06/03 01:51:49 PM]  - Fates.TERMINATE_BACK: 297 (of 331)
# [INFO][2020/06/03 01:51:49 PM]  - Fates.LINK: 3173 (of 5615)
# [INFO][2020/06/03 01:51:49 PM]  - Fates.DIVIDE: 549 (of 1084)
# [INFO][2020/06/03 01:51:49 PM]  - Fates.INITIALIZE_FRONT: 193 (of 222)
# [INFO][2020/06/03 01:51:49 PM]  - Fates.FALSE_POSITIVE: 3260 (of 12870)
# [INFO][2020/06/03 01:51:49 PM]  - TOTAL: 45309 hypotheses
# [INFO][2020/06/03 01:51:50 PM] Opening HDF file: /home/nathan/data/fucci/HDF/segmented.hdf5
# [INFO][2020/06/03 01:51:50 PM] ['obj_type_1']
# [INFO][2020/06/03 01:51:51 PM] Writing tracks to HDF file: /home/nathan/data/fucci/HDF/segmented.hdf5
# [WARNING][2020/06/03 01:51:51 PM] Removing obj_type_1 from HDF file.
# [INFO][2020/06/03 01:51:51 PM] Writing dummies to HDF file: /home/nathan/data/fucci/HDF/segmented.hdf5
# [INFO][2020/06/03 01:51:51 PM] Writing LBEPR to HDF file: /home/nathan/data/fucci/HDF/segmented.hdf5
# [INFO][2020/06/03 01:51:51 PM] Writing track fates to HDF file: /home/nathan/data/fucci/HDF/segmented.hdf5
# [INFO][2020/06/03 01:51:52 PM] Closing HDF file: /home/nathan/data/fucci/HDF/segmented.hdf5
# [INFO][2020/06/03 01:51:52 PM] Ending BayesianTracker session
# tick

# %%
import arboretum

from skimage import io
#seg = io.imread('/home/nathan/data/fucci/other_mask_data/segmented_v5.tif')
arboretum.run()
# Out:
# [INFO][2020/06/03 01:06:31 pm] Opening HDF file: /home/nathan/data/fucci/HDF/segmented.hdf5
# [INFO][2020/06/03 01:06:31 pm] Loading tracks: obj_type_1...
# [WARNING][2020/06/03 01:06:32 pm] Labels missing from objects in HDF file
# [INFO][2020/06/03 01:06:34 pm] Loading obj_type_1 (243739, 5) (234878 filtered: area>=50)...
# [INFO][2020/06/03 01:06:37 pm] Closing HDF file: /home/nathan/data/fucci/HDF/segmented.hdf5
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/napari/_qt/threading.py in reraise(e)
#     518
#     519         def reraise(e):
# --> 520             raise e
#     521
#     522         worker.errored.connect(reraise)
#
# ~/anaconda3/lib/python3.7/site-packages/napari/_qt/threading.py in run(self)
#     113         self._running = True
#     114         try:
# --> 115             result = self.work()
#     116             self.returned.emit(result)
#     117         except Exception as exc:
#
# ~/anaconda3/lib/python3.7/site-packages/napari/_qt/threading.py in work(self)
#     213
#     214     def work(self):
# --> 215         return self._func(*self._args, **self._kwargs)
#     216
#     217
#
# ~/anaconda3/lib/python3.7/site-packages/arboretum/core.py in _import()
#     136             _, ext = os.path.splitext(arbor.filename)
#     137             if ext in ('.hdf5',):
# --> 138                 seg, tracks = utils.load_hdf(arbor.filename)
#     139                 arbor.segmentation = seg
#     140                 arbor.tracks = tracks
#
# ~/anaconda3/lib/python3.7/site-packages/arboretum/utils.py in load_hdf(filename, filter_by, load_segmentation, color_segmentation)
#     184
#     185         if 'tracks' in h._hdf:
# --> 186             tracks = h.tracks
#     187         else:
#     188             tracks = []
#
# ~/anaconda3/lib/python3.7/site-packages/btrack/dataio.py in tracks(self)
#     489                 idx = slice(*track_map[i,:].tolist())
#     490                 refs = track_refs[idx]
# --> 491                 track = btypes.Tracklet(lbep[i,0], list(map(get_txyz, refs)))
#     492                 track.parent = lbep[i,3]    # set the parent and root of tree
#     493                 track.root = lbep[i,4]
#
# ~/anaconda3/lib/python3.7/site-packages/btrack/dataio.py in get_txyz(ref)
#     482
#     483             def get_txyz(ref):
# --> 484                 if ref>=0: return obj[ref]
#     485                 return dobj[abs(ref)-1] # references are -ve for dummies
#     486
#
# IndexError: list index out of range
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/napari/_qt/threading.py in reraise(e)
#     518
#     519         def reraise(e):
# --> 520             raise e
#     521
#     522         worker.errored.connect(reraise)
#
# ~/anaconda3/lib/python3.7/site-packages/napari/_qt/threading.py in run(self)
#     113         self._running = True
#     114         try:
# --> 115             result = self.work()
#     116             self.returned.emit(result)
#     117         except Exception as exc:
#
# ~/anaconda3/lib/python3.7/site-packages/napari/_qt/threading.py in work(self)
#     213
#     214     def work(self):
# --> 215         return self._func(*self._args, **self._kwargs)
#     216
#     217
#
# ~/anaconda3/lib/python3.7/site-packages/arboretum/core.py in _import()
#     140                 arbor.tracks = tracks
#     141             elif ext in ('.json',):
# --> 142                 tracks = utils.load_json(arbor.filename)
#     143                 arbor.tracks = [tracks]
#     144
#
# ~/anaconda3/lib/python3.7/site-packages/arboretum/utils.py in load_json(filename)
#     207         cell_type = 'None'
#     208
# --> 209     tracks = btrack.dataio.import_all_tracks_JSON(filepath, cell_type=cell_type)
#     210     return tracks
#     211
#
# ~/anaconda3/lib/python3.7/site-packages/btrack/dataio.py in import_all_tracks_JSON(folder, cell_type)
#     218     tracks = []
#     219     # check to see whether this is a zipped file
# --> 220     as_zipped = track_files[cell_type]['zipped']
#     221     if as_zipped:
#     222         import zipfile
#
# KeyError: 'v5'

# %% [markdown]
# # export to xml

# %%
def export_to_FIJI(filename, tracks, trees=[]):
    import json
    import xml.etree.cElementTree as ET
    root = ET.Element("data", name=filename)
    for trk in tracks:
        trajectory = ET.SubElement(root, "trajectory", id=str(int(trk.ID)))
        ET.SubElement(trajectory, "root").text = str(trk.root)
        ET.SubElement(trajectory, "length").text = str(len(trk))
        ET.SubElement(trajectory, "fate").text = str(trk.fate.value)
        ET.SubElement(trajectory, "x").text = str([float("{0:2.1f}".format(x)) for x in trk.x])
        ET.SubElement(trajectory, "y").text = str([float("{0:2.1f}".format(y)) for y in trk.y])
        ET.SubElement(trajectory, "n").text = str([int(t) for t in trk.t])
        ET.SubElement(trajectory, "class").text = str([l.lower() for l in trk.label])
        if trk.parent != 0:
            # ET.SubElement(trajectory, "parent").text = str(trk.parent-1)
            # NOTE(arl): need to check whether this -1 on the index is required
            ET.SubElement(trajectory, "parent").text = str(trk.parent)
        else:
            ET.SubElement(trajectory, "parent").text = str(None)
        if trk.children:
            ET.SubElement(trajectory, "children").text = str(trk.children)
    for tree in trees:
        lin_tree = lineage.linearise_tree(tree)
        if len(lin_tree) > 1:
            root_node = lin_tree.pop(0)
            this_tree = ET.SubElement(root, "tree", root_id=str(root_node.ID))
            for child in lin_tree:
                ET.SubElement(this_tree, "child").text = str(child.ID)
    XMLtree = ET.ElementTree(root)
    XMLtree.write(filename)

# %%
export_to_FIJI('/home/nathan/analysis/segmented.xml', tracks)
